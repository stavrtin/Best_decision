# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=5>
# <b>
#     Загружаем данные из 605го<br> -----------и ЕЛГ_Архив
#     </b><br>
#     </div>
# <hr>
#     <nav>
# <a href=https://docs.google.com/spreadsheets/d/1HFS-EJVlxGjopkdv9QPuqVAgczX3nQajaEV0qfPvKgU/edit#gid=2061456016>ЕЛГ из архива</a> |
# </nav>

# %%
data_605 = pd.read_csv('605_0203.csv', delimiter=';', encoding='cp1251')
# data_elg = pd.read_csv('ЕЛГ_госп.csv', delimiter=';', encoding='cp1251')

print(data_605.shape)
# print(data_elg.shape)
# Out:
# (91097, 26)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b>
#     Убираем лишние колонки для 605го и переименовываем
#     </b>
#     </div>
# <hr>

# %%
# как4ие есть колонки
data_605.columns
# Out:
# Index(['ID  пациента', 'Дата постановки на учет/включения пациента в реестр',
#        'Пациент', 'Пол', 'Дата рождения', 'Гражданский статус', 'Адрес',
#        'Адрес фактический', 'Документ удостоверяющий личность', 'Серия/№',
#        'Кем выдан',
#        'Свидетельство о регистрации по месту жительства(до 14 лет)', 'СНИЛС',
#        'Полис ОМС', 'Наличие инвалидности', 'Основной диагноз по МКБ-10',
#        'Основное контактное лицо',
#        'Дата признания пациента нуждающимся в ПМП (ВК)',
#        'Тип документа о признании паллиативным',
#        'Медицинская организация, в которой признали пациента нуждающимся в ПМП',
#        'Наличие разрешения ДЗМ на оказание помощи', 'Дата разрешения ДЗМ',
#        'Номер разрешения ДЗМ', 'Текущий статус пациента',
#        'Дата прекращения оказания ПМП', 'Курирующее подразделение/филиал'],
#       dtype='object')

# %%
# уберем лишние колонки
df_605 = data_605.copy()
df_605 = df_605[['Дата постановки на учет/включения пациента в реестр',
       'Пациент', 
       'Дата рождения', 'Пол',
       'Дата признания пациента нуждающимся в ПМП (ВК)',
       'Текущий статус пациента',
       'Дата прекращения оказания ПМП', 
         'Курирующее подразделение/филиал',
               'Гражданский статус',
               'Основной диагноз по МКБ-10' ]]
df_605.head(2)
# Out:
#   Дата постановки на учет/включения пациента в реестр  \
# 0                                         02.02.2023
# 1                                         15.05.2020
#
#                             Пациент Дата рождения      Пол  \
# 0  Зинатшина Анастасия Владимировна    22.09.1986  Женский
# 1        Волченкова Юлия Викторовна    22.05.1983  Женский
#
#   Дата признания пациента нуждающимся в ПМП (ВК)  Текущий статус пациента  \
# 0                                     31.01.2023                     Умер
# 1                                     09.03.2022  Прекращено оказание ПМП
#
#   Дата прекращения оказания ПМП Курирующее подразделение/филиал  \
# 0                    03.02.2023                 Зеленоград ОВПП
# 1                    17.01.2023                 Зеленоград ОВПП
#
#   Гражданский статус                  Основной диагноз по МКБ-10
# 0            Москвич                       C00 - D48 (онкология)
# 1            Москвич  (C00- С97) Злокачественные новообразования

# %%
#  переименуем покороче столбцы
df_605.rename(columns={'Дата постановки на учет/включения пациента в реестр': 'Дата_вкл_реестр'}, inplace=True)
df_605.rename(columns={'Дата рождения': 'ДР'}, inplace=True)
df_605.rename(columns={'Дата признания пациента нуждающимся в ПМП (ВК)': 'Дата_признания'}, inplace=True)
df_605.rename(columns={'Дата прекращения оказания ПМП': 'Дата_прекр'}, inplace=True)
df_605.rename(columns={'Курирующее подразделение/филиал': 'Филиал'}, inplace=True)
df_605.rename(columns={'Гражданский статус': 'Иногород'}, inplace=True)
df_605.rename(columns={'Основной диагноз по МКБ-10': 'Диагноз'}, inplace=True)

df_605.head(2)
# Out:
#   Дата_вкл_реестр                           Пациент          ДР      Пол  \
# 0      02.02.2023  Зинатшина Анастасия Владимировна  22.09.1986  Женский
# 1      15.05.2020        Волченкова Юлия Викторовна  22.05.1983  Женский
#
#   Дата_признания  Текущий статус пациента  Дата_прекр           Филиал  \
# 0     31.01.2023                     Умер  03.02.2023  Зеленоград ОВПП
# 1     09.03.2022  Прекращено оказание ПМП  17.01.2023  Зеленоград ОВПП
#
#   Иногород                                     Диагноз
# 0  Москвич                       C00 - D48 (онкология)
# 1  Москвич  (C00- С97) Злокачественные новообразования

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b>
#     Аналогично для ЕЛГ (Убираем лишние колонки и переименовываем)
#     </b>
#     </div>
# <hr>

# %%
# как4ие есть колонки
# data_elg.columns

# %%
# уберем лишние колонки
# df_elg = data_elg.copy()
# df_elg = df_elg[[ 'Фамилия',        'Имя', 'Отчество',  'Дата рождения',
#        'Дата постановки на учет',
      
#        'Филиал \nгоспитализации', 
#         'Фактическая дата госпитализации', 
#         'Дата фактического выбытия',
#         'Причина выбытия' ]]
# df_elg.head(2)

# %%
#  -------------------переименуем покороче столбцы ЕЛГ
# df_elg.rename(columns={'Дата постановки на учет': 'Дата_вкл_реестр'}, inplace=True)
# df_elg.rename(columns={'Дата рождения': 'ДР'}, inplace=True)
# df_elg.rename(columns={'Филиал \nгоспитализации': 'Филиал'}, inplace=True)
# df_elg.rename(columns={'Причина выбытия': 'Текущий статус пациента'}, inplace=True)
# df_elg.rename(columns={'Фактическая дата госпитализации': 'Дата_госпит'}, inplace=True)
# df_elg.rename(columns={'Дата фактического выбытия': 'Дата_выбытия'}, inplace=True)
# df_elg.head(2)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> ЕЛГ </b><br>
#     Добавим новый признак <b>Дата_прекр</b> и заполним его значение из <b>Дата выбытия</b>, если пациент умер<br>
#     новые признаки для женитьбы с 605м<br>
#     новый признак ПАЦИЕНТ (соединим фам им и отч)<br>
#     удалим лишние колонки из ЕЛГ для послед женитьбы с 605 реестром<br>
#         </div>
# <hr>

# %%
# df_elg['Текущий статус пациента'].unique()

# %%
# --------------- новые признаки для женитьбы с 605м ------------------
# df_elg['Дата_прекр'] = np.nan
# df_elg['Пациент'] = np.nan
# df_elg['Дата_признания'] = np.nan

# %%
# df_elg.loc[ (df_elg['Текущий статус пациента'] == 'Пациент скончался')
#             | (df_elg['Текущий статус пациента'] == 'пациент скончался')
#             | (df_elg['Текущий статус пациента'] == 'пациентка скончалась')
#             | (df_elg['Текущий статус пациента'] == 'Пациент скончался в присутствии родственников'), 'Дата_прекр' ] = df_elg['Дата_выбытия']
# df_elg.shape

# %%
# --------- новый признак ПАЦИЕНТ (соединим фам им и отч) ------------
# df_elg['Пациент' ] = df_elg['Фамилия'] + ' ' +  df_elg['Имя'] + ' ' + df_elg['Отчество']

# %%
#  -------------- 
# df_elg['Дата_признания' ] = df_elg['Дата_вкл_реестр']

# %%
# ---- удалим лишние колонки из ЕЛГ для послед женитьбы с 605 реестром ----------
# df_elg = df_elg[[ 'Дата_вкл_реестр',    'Пациент',  'ДР','Дата_признания',
#        'Текущий статус пациента',        'Дата_прекр',         'Филиал' ]]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> ЕЛГ и 605й</b><br>
#     Получили подготовленные датафреймы с однак.полями для женитьбы
#         </div>
# <hr>

# %%
# df_elg.head()

# %%
df_605.head()
# Out:
#   Дата_вкл_реестр                           Пациент          ДР      Пол  \
# 0      02.02.2023  Зинатшина Анастасия Владимировна  22.09.1986  Женский
# 1      15.05.2020        Волченкова Юлия Викторовна  22.05.1983  Женский
# 2             NaN     Шкуренко Вячеслав Геннадьевич  06.10.1978  Мужской
# 3      12.01.2023       Мазурова Надежда Алексеевна  02.05.1976  Женский
# 4      17.11.2022        Демьянович Дмитрий Юрьевич  08.03.1969  Мужской
#
#   Дата_признания  Текущий статус пациента  Дата_прекр           Филиал  \
# 0     31.01.2023                     Умер  03.02.2023  Зеленоград ОВПП
# 1     09.03.2022  Прекращено оказание ПМП  17.01.2023  Зеленоград ОВПП
# 2     14.02.2023              Вне реестра         NaN  Зеленоград ОВПП
# 3            NaN                 Патронаж         NaN  Зеленоград ОВПП
# 4     16.11.2022            Стационар ЦПП         NaN  Зеленоград ОВПП
#
#   Иногород                                     Диагноз
# ...

# %% [markdown]
# <hr>
# <div class="alert alert-block alert-warning">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> ЕЛГ и 605й. Соединим данные по 605му и по ЕЛГ</b><br>
#             </div>
# <hr>

# %%
print(df_605.shape)
# Out:
# (91097, 10)

# %%
# df_concat = pd.concat([df_605,df_elg])
df_concat = pd.concat([df_605])
df_concat.shape
# Out:
# (91097, 10)

# %% [markdown]
# <hr>
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> Заменим статус СКОНЧАЛСЯ на УМЕР, Переводы на Стационар ЦПП и  Перевод в соц.учреждение на Патронаж</b><br>
#             </div>
# <hr>

# %%
df_concat['Текущий статус пациента'].unique()
# Out:
# array(['Умер', 'Прекращено оказание ПМП', 'Вне реестра', 'Патронаж',
#        'Стационар ЦПП', 'Новый пациент', 'Умер без п/о',
#        'Госпитализация в ОПМП', 'Врач КЦ', nan], dtype=object)

# %%
# ----- заменим статусы скончался на УМЕР ------------
# df_concat.loc[(df_concat['Текущий статус пациента'] == 'Пациент скончался')
#             | (df_concat['Текущий статус пациента'] == 'пациент скончался')
#             | (df_concat['Текущий статус пациента'] == 'пациентка скончалась')
#             | (df_concat['Текущий статус пациента'] == 'Пациент скончался в присутствии родственников'), 'Текущий статус пациента' ] = "Умер"

# %%
# ----- заменим статусы Перевод между хосписами на Стационар ЦПП ------------
# df_concat.loc[(df_concat['Текущий статус пациента'] == 'Перевод между хосписами')
            # # | (df_concat['Текущий статус пациента'] == 'Перевод в другое ЛПУ')
            # # | (df_concat['Текущий статус пациента'] == 'Перевод в соц.учреждение')
            # | (df_concat['Текущий статус пациента'] == 'Перевод между отделениями в ЦПП')
            #   | (df_concat['Текущий статус пациента'] == 'перевод между хосписами')
            # # | (df_concat['Текущий статус пациента'] == 'Перевод в соц.учреждене')
            #   , 'Текущий статус пациента' ] = "Стационар ЦПП"

# ----- заменим статусы Перевод в другое ЛПУ на Стационар ЦПП ------------
# df_concat.loc[ (df_concat['Текущий статус пациента'] == 'Перевод в другое ЛПУ')
#             | (df_concat['Текущий статус пациента'] == 'Перевод в соц.учреждение')
#             # | (df_concat['Текущий статус пациента'] == 'Перевод между отделениями в ЦПП')
#               # | (df_concat['Текущий статус пациента'] == 'перевод между хосписами')
#             | (df_concat['Текущий статус пациента'] == 'Перевод в соц.учреждене')
#             | (df_concat['Текущий статус пациента'] == 'выписка пациента')
#               | (df_concat['Текущий статус пациента'] == 'Выписка домой')
              
#             , 'Текущий статус пациента' ] = "Патронаж"
# df_concat.shape

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> Приведем ДАТЫ к фрмату ДАТА</b><br>
#             </div>

# %%
# df_concat

# %%
# ----------------форматнем дату к дате
df_concat['ДР'] = pd.to_datetime(df_concat['ДР'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_вкл_реестр'] = pd.to_datetime(df_concat['Дата_вкл_реестр'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_признания'] = pd.to_datetime(df_concat['Дата_признания'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_прекр'] = pd.to_datetime(df_concat['Дата_прекр'], dayfirst=True, errors = 'coerce').dt.normalize()

# %%
df_concat.shape
# Out:
# (91097, 10)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> Оставим только НУЖНЫЕ СТАТУСЫ (Уберем записи со СТАТУСОМ  'Умер без п/о', 'Новый пациент', 'Вне реестра', 'Врач КЦ')  <br>
# </b>            </div>

# %%
# Уберем записи со СТАТУСОМ  'Умер без п/о', 'Новый пациент', 'Вне реестра', 'Врач КЦ'
# - удаляем строки. в которых текущий статус не заполнен =  nan
df_concat = df_concat.loc[(~df_concat['Текущий статус пациента'].isin(['Новый пациент', 'Умер без п/о', 'Вне реестра', 'Врач КЦ']))] 
df_concat = df_concat.loc[(~df_concat['Текущий статус пациента'].isna())]  # - удаляем строки. в которых текущий статус не заполнен =  nan
df_concat.shape
# Out:
# (86846, 10)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> БМЧУ "Детский хоспис  <br>
# </b>            </div>

# %%
# Уберем 'БМЧУ "Детский хоспис"' из наших данных
df_concat = df_concat.loc[df_concat['Филиал'] != 'БМЧУ "Детский хоспис"']  # - удаляем строки. в которых текущий статус не заполнен =  nan
df_concat.shape
# Out:
# (86196, 10)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> # новый признак - Дата_первых_сведений  <br>
# </b>            </div>

# %%
# Заполним поле Дата_первых_сведений данными: 
#  если Дата_вкл_реестр не пустая, то  Дата_учета = Дата_вкл_реестр

df_concat.loc[ (~df_concat['Дата_вкл_реестр'].isnull()) , 'Дата_первых_сведений'] = df_concat['Дата_вкл_реестр']
df_concat.loc[ (df_concat['Дата_вкл_реестр'].isnull()) & (~df_concat['Дата_признания'].isnull()) , 'Дата_первых_сведений'] = df_concat['Дата_признания']
df_concat.loc[ (df_concat['Дата_вкл_реестр'].isnull()) & (df_concat['Дата_признания'].isnull()) & (~df_concat['Дата_прекр'].isnull()) , 'Дата_первых_сведений'] = df_concat['Дата_прекр'] - pd.Timedelta(days = 2)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> # новый признак - Дата_выбытия  <br>
# </b>            </div>

# %%
# новый признак - Дата_прекр_2

# 1 -- условие ---------------------------
df_concat.loc[ (  
           ((df_concat['Дата_прекр'].isnull()) & (df_concat['Дата_вкл_реестр'] < '2020-12-31'))  
        &  (  (df_concat['Текущий статус пациента'] == 'Умер') | (df_concat['Текущий статус пациента'] == 'Прекращено оказание ПМП') )
           )
           , 'Дата_выбытия'] = '01.01.1900'

# 2 -- условие----------------------------
df_concat.loc[(~df_concat['Дата_прекр'].isnull()), 'Дата_выбытия'] = df_concat['Дата_прекр']

# 3 -- условие ---------------------------
df_concat.loc[
                 (~df_concat['Дата_первых_сведений'].isnull() & df_concat['Дата_выбытия'].isnull() )  
              &  ((df_concat['Текущий статус пациента'] == 'Умер') | (df_concat['Текущий статус пациента'] == 'Прекращено оказание ПМП')), 'Дата_выбытия'] = df_concat['Дата_первых_сведений'] + pd.Timedelta(days = 2)

# %%
# df_concat.loc[
#                  (~df_concat['Дата_первых_сведений'].isnull() & df_concat['Дата_выбытия'].isnull() )  
#               &  ((df_concat['Текущий статус пациента'] == 'Умер') | (df_concat['Текущий статус пациента'] == 'Прекращено оказание ПМП')), 'Дата_выбытия'] = df_concat['Дата_первых_сведений'] + pd.Timedelta(days = 2)

# %%
# df_concat.loc[(~df_concat['Дата_первых_сведений'].isnull() )  &  ((df_concat['Текущий статус пациента'] == 'Умер') | (df_concat['Текущий статус пациента'] == 'Прекращено оказание ПМП'))]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> # Еще раз форматнем ДАТЫ  <br>
# </b>            </div>

# %%
# ----------------форматнем дату к дате
df_concat['ДР'] = pd.to_datetime(df_concat['ДР'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_вкл_реестр'] = pd.to_datetime(df_concat['Дата_вкл_реестр'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_признания'] = pd.to_datetime(df_concat['Дата_признания'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_прекр'] = pd.to_datetime(df_concat['Дата_прекр'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_выбытия'] = pd.to_datetime(df_concat['Дата_выбытия'], dayfirst=True, errors = 'coerce').dt.normalize()
df_concat['Дата_первых_сведений'] = pd.to_datetime(df_concat['Дата_первых_сведений'], dayfirst=True, errors = 'coerce').dt.normalize()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Считаем возраст  <br>
# </b>            </div>

# %%
# ------------подсчитаем ВОЗРАСТ --------------

now = pd.Timestamp('now')
df_concat.loc[(df_concat['Текущий статус пациента'] == 'Умер') & (~df_concat['Дата_выбытия'].isnull()), 'Возраст'] = (df_concat['Дата_выбытия'] - df_concat['ДР']).dt.days//365
df_concat.loc[(df_concat['Текущий статус пациента'] != 'Умер'), 'Возраст'] = (now - df_concat['ДР']).astype('<m8[Y]')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Признак "ТРУДОСПОСОБНЫЕ"  <br>
# </b>            </div>

# %%
#  ------ посчитаем категорию трудоспособный --------
#  если пол ЖЕНСКИЙ, и возраст Менее 57 -----> Категория - трудоспособный
#  если пол Мужской, и возраст Менее 62 -----> Категория - трудоспособный

df_concat['Категория'] = np.nan
df_concat.loc[(df_concat['Возраст'] >= 18) & (df_concat['Пол'] == 'Мужской') & (df_concat['Возраст'] >= 62), 'Категория'] = 'Старше трудосп'
df_concat.loc[(df_concat['Возраст'] >= 18) & (df_concat['Пол'] == 'Женский') & (df_concat['Возраст'] >= 57), 'Категория'] = 'Старше трудосп'

df_concat
# Out:
#       Дата_вкл_реестр                           Пациент         ДР      Пол  \
# 0          2023-02-02  Зинатшина Анастасия Владимировна 1986-09-22  Женский
# 1          2020-05-15        Волченкова Юлия Викторовна 1983-05-22  Женский
# 3          2023-01-12       Мазурова Надежда Алексеевна 1976-05-02  Женский
# 4          2022-11-17        Демьянович Дмитрий Юрьевич 1969-03-08  Мужской
# 5          2023-01-28    Кудрявцева Светлана Викторовна 1968-02-22  Женский
# ...               ...                               ...        ...      ...
# 91092      2099-08-07   Муллаянов Рафаиль Мухлисуллович 1954-11-13  Мужской
# 91093      2202-04-12           Еникова  Феня Мартковна 1925-11-18  Женский
# 91094      2221-05-02  Тимофеева Татьяна Константиновна 1936-06-20  Женский
# 91095             NaT          Оганян Рафаел  Суренович 1957-07-02  Мужской
# 91096             NaT       Кузьмина Наталия Алексеевна 1965-09-02  Женский
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Признак "ДЕТИ"  <br>
# </b>            </div>

# %%
#  ------ определим детей ---------------
df_concat['Дети'] = np.nan
df_concat.loc[(df_concat['Возраст'] < 18) & (df_concat['Возраст'] >= 0), 'Дети'] = 'Дети'
# df_concat['Дети'].count()
# df_concat

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Признак "ПРОДОЛЖИТЕЛЬНОСТЬ НАБЛЮДЕНИЯ"  <br>
# </b>            </div>

# %%
# ---- новый признак ПРОДОРЛЖИТЕЛЬНОСТЬ-----
df_concat["Длителность_наблюдения"] = np.nan

# %%
# pd.to_datetime('today').normalize()

# %%
today_date = pd.to_datetime(pd.to_datetime('today').normalize(), dayfirst=True, errors = 'coerce').normalize()
today_date
# Out:
# Timestamp('2023-03-07 00:00:00')

# %%
# df_concat.loc[df_concat["Длителность_наблюдения"].isna()]

# %%
df_concat["Длителность_наблюдения"] = df_concat["Дата_выбытия"] - df_concat["Дата_первых_сведений"]
df_concat.sample(7)
# Out:
#       Дата_вкл_реестр                          Пациент         ДР      Пол  \
# 36258      2019-06-12        Сиганов Сергей Николаевич 1963-06-30  Мужской
# 63764      2021-04-07       Варцева Елена Владимировна 1969-06-29  Женский
# 65824      2021-06-02        Сергеев Станислав Кузьмич 1941-08-11  Мужской
# 15151      2017-08-03        Щукина Анастасия Ивановна 1922-09-04  Женский
# 2353       2022-11-07      Мамедова Эльмира Эльшановна 2016-07-25  Женский
# 55750      2020-09-09  Романцов Александр Владимирович 1950-05-17  Мужской
# 83985      2022-09-29         Шабунин Игорь Алексеевич 1946-10-26  Мужской
#
#       Дата_признания  Текущий статус пациента Дата_прекр           Филиал  \
# 36258     2019-06-05  Прекращено оказание ПМП 2022-06-06   Ростокино ОВПП
# 63764     2021-03-29                     Умер 2022-04-03    Хорошево ОВПП
# 65824            NaT                     Умер 2021-06-13    Царицыно ОВПП
# ...

# %%
# Если пациент не выбыл (дата выбыти НАН) то вычитаем из СЕГОДНЯ
df_concat.loc[df_concat["Длителность_наблюдения"].isna(), 'Длителность_наблюдения'] = today_date - df_concat["Дата_первых_сведений"]
df_concat.sample(7)
# Out:
#       Дата_вкл_реестр                        Пациент         ДР      Пол  \
# 66723      2021-06-28   Егорова Екатерина Васильевна 1947-04-23  Женский
# 32069      2019-03-05       Юсин Владимир Николаевич 1959-04-08  Мужской
# 25053      2018-08-23       Ходжаев Марат Гайнанович 1961-06-30  Мужской
# 824        2022-09-26  Елисеев Владимир Вячеславович 1932-08-01  Мужской
# 54523      2020-08-12       Винокурова Нина Павловна 1933-11-28  Женский
# 63491      2021-03-31     Морозова Клавдия Сергеевна 1936-07-15  Женский
# 82542      2022-08-26    Ибрагимов Марат Магомедович 1990-09-18  Мужской
#
#       Дата_признания Текущий статус пациента Дата_прекр           Филиал  \
# 66723            NaT                Патронаж        NaT   Ростокино ОВПП
# 32069            NaT                    Умер 2020-03-03  Некрасовка ОВПП
# 25053            NaT                    Умер        NaT      Бутово ОВПП
# 824       2022-09-22                Патронаж        NaT  Зеленоград ОВПП
# ...

# %% [markdown]
# ###
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b>Распишем ДИАГНОЗЫ </b>

# %%
# ---- новый Признак ДИАГНОЗА проставлен-----
df_concat["признак_Диагноза"] = np.nan

# %% [markdown]
# #### Онко
# <hr>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Признак "ОНКО"  <br>
# </b>
#     список слов: "рак", "зно", "образовани" , "онкол" , "миелом" , "опухо" , "мтс" , "пммр" , "злокач" , "mts" , "злокач" , "злокач" , "сарко" , "лейкоз"</div>

# %%
# ---- новый признак Онкология-----
df_concat["Онкология"] = np.nan

# %%
# ----- к нижнему регистру, все, что  в Основной диагноз
df_concat['Диагноз'] = df_concat['Диагноз'].str.lower()

# %%
df_concat.loc[
             (df_concat['Диагноз'].str.contains("рак") == True)           
          |(df_concat['Диагноз'].str.contains("зно") == True)           
          |(df_concat['Диагноз'].str.contains("образовани") == True)           
          |(df_concat['Диагноз'].str.contains("онкол") == True)           
          |(df_concat['Диагноз'].str.contains("миелом") == True)           
          |(df_concat['Диагноз'].str.contains("опухо") == True)    
          |(df_concat['Диагноз'].str.contains("мтс") == True)  
          |(df_concat['Диагноз'].str.contains("пммр") == True)  
          |(df_concat['Диагноз'].str.contains("злокач") == True)  
          |(df_concat['Диагноз'].str.contains("mts") == True)  
          |(df_concat['Диагноз'].str.contains("злокач") == True)  
          |(df_concat['Диагноз'].str.contains("злокач") == True)  
          |(df_concat['Диагноз'].str.contains("сарко") == True)  
    
    
          |(df_concat['Диагноз'].str.contains("лейкоз") == True)  
          |(df_concat['Диагноз'].str.contains("c00") == True)  
          |(df_concat['Диагноз'].str.contains("c97") == True)  
          |(df_concat['Диагноз'].str.contains("d48") == True) 
    
    
              |(df_concat['Диагноз'].str.contains("с00") == True)  
          |(df_concat['Диагноз'].str.contains("с97") == True)  
          |(df_concat['Диагноз'].str.contains("d48") == True) 
           
          |(df_concat['Диагноз'].str.contains("c43") == True) 
          |(df_concat['Диагноз'].str.contains("d32") == True) 
          |(df_concat['Диагноз'].str.contains("c16") == True) 
          |(df_concat['Диагноз'].str.contains("c34") == True) 
     
     |(df_concat['Диагноз'].str.contains("с80") == True) 
     |(df_concat['Диагноз'].str.contains("с18") == True) 
     |(df_concat['Диагноз'].str.contains("глиобластома головного мозга") == True)  
    
                # |(df_gosp['Диагноз'].str.contains("d48") == True)  
                # |(df_gosp['Диагноз'].str.contains("d48") == True)  
, 'Онкология' ] = 'Onko'

df_concat.loc[~df_concat['Онкология'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### НЕВРОЛОГИЯ
# <hr>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Признак "НЕВРОЛОГИЯ"  <br></b>

# %%
# ---- новый признак Неврология-----
df_concat["Неврология"] = np.nan

# %%
# df_concat.loc[df_concat['Диагноз'].str.contains("(неврология)") == True]

# %%
# ---- --------------------------- признак Неврология-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains("неврология") == True)           
          |(df_concat['Диагноз'].str.contains("g00 - g99") == True)           
          |(df_concat['Диагноз'].str.contains("g00-g98") == True)           
          |(df_concat['Диагноз'].str.contains("g00") == True)           
          |(df_concat['Диагноз'].str.contains("болезни нервной системы") == True)           

    
#                 |(df_gosp['Диагноз'].str.contains("d48") == True)  
#                 |(df_gosp['Диагноз'].str.contains("d48") == True)  
#                 |(df_gosp['Диагноз'].str.contains("d48") == True)  
, 'Неврология' ] = 'Неврология'

df_concat.loc[~df_concat['Неврология'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### Терапия
# <hr>

# %%
# ------------------------------------------ новый признак Терапия-----
df_concat["Терапия"] = np.nan

# %%
# --------------------------------------- новый признак Терапия-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains(" болезни системы кровообращения") == True)  
           | (df_concat['Диагноз'].str.contains("i00-i99") == True)
    
           | (df_concat['Диагноз'].str.contains("k00-k93") == True)
           | (df_concat['Диагноз'].str.contains("болезни органов пищеварения") == True)
    
           | (df_concat['Диагноз'].str.contains("j00-j99") == True)
           | (df_concat['Диагноз'].str.contains("болезни органов дыхания") == True)
    
           | (df_concat['Диагноз'].str.contains("m00-m99") == True)
           | (df_concat['Диагноз'].str.contains("костно-мышечной") == True)
    
           | (df_concat['Диагноз'].str.contains("n00-n99") == True)
           | (df_concat['Диагноз'].str.contains("мочеполовой системы") == True)
    
           | (df_concat['Диагноз'].str.contains("d82") == True)
    
           | (df_concat['Диагноз'].str.contains("d50-d89") == True)
           | (df_concat['Диагноз'].str.contains("болезни крови, кроветворных") == True)
           
           | (df_concat['Диагноз'].str.contains("цвб хигм") == True)
    
           | (df_concat['Диагноз'].str.contains("м00-м050") == True)
   
#            | (df_concat['Диагноз'].str.contains("м00-м050") == True)
#            | (df_concat['Диагноз'].str.contains("болезни органов дыхания") == True)

    
    
    
, 'Терапия' ] = 'Терапия'

df_concat.loc[~df_concat['Терапия'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### Педиатрия
# <hr>

# %%
# ----------------------------------------- новый признак Педиатрия-----
df_concat["Педиатрия"] = np.nan

# %%
# --------------------------------------- новый признак Педиатрия-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains("p00-p96") == True)  
           | (df_concat['Диагноз'].str.contains("отдельные состояния, возникающие") == True)
           | (df_concat['Диагноз'].str.contains("р00-р96") == True)
           # | (df_concat['Диагноз'].str.contains("s00-t98") == True)
           # | (df_concat['Диагноз'].str.contains("травмы, отравления и некоторые") == True)

    , 'Педиатрия' ] = 'Педиатрия'

df_concat.loc[~df_concat['Педиатрия'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### Врожденные_аномалии
# <hr>

# %%
# ----------------------------------------- новый признак Врожденные_аномалии-----
df_concat["Врожденные"] = np.nan

# %%
# --------------------------------------- новый признак Врожденные_аномалии-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains("q00-q99") == True)  
           | (df_concat['Диагноз'].str.contains("пороки развития") == True)
    
           # | (df_concat['Диагноз'].str.contains("диагнозтест") == True)
           # | (df_concat['Диагноз'].str.contains("s00-t98") == True)

    , 'Врожденные' ] = 'Врожденные'

df_concat.loc[~df_concat['Врожденные'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### ВИЧ-инфекция
# <hr>

# %%
# ----------------------------------------- новый признак ВИЧ-----
df_concat["ВИЧ"] = np.nan

# %%
# --------------------------------------- новый признак ВИЧ-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains("в20.7") == True)  
           | (df_concat['Диагноз'].str.contains("вич-инфекция") == True)
    
           # | (df_concat['Диагноз'].str.contains("диагнозтест") == True)
           # | (df_concat['Диагноз'].str.contains("s00-t98") == True)

    , 'ВИЧ' ] = 'ВИЧ'

df_concat.loc[~df_concat['ВИЧ'].isna(), 'признак_Диагноза'] = 'Есть'

# %%
df_concat.loc[df_concat['признак_Диагноза'].isna()]
# Out:
#       Дата_вкл_реестр                         Пациент         ДР      Пол  \
# 121        2020-11-19     Карачков Алексей Викторович 1979-11-25  Мужской
# 135        2022-07-20       Апсова Оксана Мухамедовна 1974-11-30  Женский
# 136        2021-11-25       Белова Елена Владимировна 1973-04-30  Женский
# 179        2022-04-22  Митрофанов Вадим Александрович 1966-03-17  Мужской
# 180        2020-01-16  Притуленко Дмитрий Григорьевич 1966-06-06  Мужской
# ...               ...                             ...        ...      ...
# 90863      2023-02-25    Васильева Антонина Андреевна 1937-10-24  Женский
# 90883      2023-02-25        Лапшина Нина Григорьевна 1937-04-04  Женский
# 90896      2023-02-25   Прокофьева Антонина Сергеевна 1938-11-25  Женский
# 91064      2023-03-01         Титов Виктор Леонидович 1956-06-15  Мужской
# 91093      2202-04-12         Еникова  Феня Мартковна 1925-11-18  Женский
#
#       Дата_признания Текущий статус пациента Дата_прекр               Филиал  \
# ...

# %%
# df_concat.loc[df_concat['Диагноз'].str.contains('вич') == True]

# %% [markdown]
# #### Психиатрия
# <hr>

# %%
# ----------------------------------------- новый признак Психиатрия-----
df_concat["Психиатрия"] = np.nan

# %%
# --------------------------------------- новый признак Психиатрия-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains("f00-f99") == True)  
           | (df_concat['Диагноз'].str.contains("психические расстройства") == True)
    
           | (df_concat['Диагноз'].str.contains("f.20") == True)
           | (df_concat['Диагноз'].str.contains("f.02") == True)
    
    
           | (df_concat['Диагноз'].str.contains("шизофрения") == True)
    
           # | (df_concat['Диагноз'].str.contains("диагнозтест") == True)
           # | (df_concat['Диагноз'].str.contains("f.20.004) шизофрения") == True)

    , 'Психиатрия' ] = 'Психиатрия'

df_concat.loc[~df_concat['Психиатрия'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### Прочие
# <hr>

# %%
# ----------------------------------------- новый признак Прочие-----
df_concat["Прочие"] = np.nan

# %%
# --------------------------------------- новый признак Прочие-----
df_concat.loc[
             (df_concat['Диагноз'].str.contains("инфекционные и паразитарные болезни") == True)  
           | (df_concat['Диагноз'].str.contains("a00-b99") == True)
           | (df_concat['Диагноз'].str.contains("диагнозтест") == True)
           | (df_concat['Диагноз'].str.contains("s00-t98") == True)
           | (df_concat['Диагноз'].str.contains("травмы, отравления и некоторые") == True)
           | (df_concat['Диагноз'].str.contains("короновирусная инфекция") == True)
           | (df_concat['Диагноз'].str.contains("r00-r99") == True)
           | (df_concat['Диагноз'].str.contains("l00-l99") == True)
           | (df_concat['Диагноз'].str.contains("болезни кожи и подкожной клетчатки") == True)
           | (df_concat['Диагноз'].str.contains("h00-h59") == True)
           | (df_concat['Диагноз'].str.contains("e00-e90") == True)
           | (df_concat['Диагноз'].str.contains("эндокринной системы") == True)
           | (df_concat['Диагноз'].str.contains("алкогольный цирроз") == True)
    
    
          | (df_concat['Диагноз'].str.contains("е00-е90") == True)
    
    
#            | (df_concat['Диагноз'].str.contains("е00-е90") == True)
#            | (df_concat['Диагноз'].str.contains("костно-мышечной") == True)

    , 'Прочие' ] = 'Прочие'

df_concat.loc[~df_concat['Прочие'].isna(), 'признак_Диагноза'] = 'Есть'

# %% [markdown]
# #### Финальное заполнение, если признаков диагноза более не обнаружено
# <hr>

# %%
# ------------------------ после всех ПРИЗНАКОВ остатки - в ПРОЧИЕ ----

# %%
df_concat.loc[df_concat['признак_Диагноза'].isna(), 'Прочие'] = 'Прочие'

df_concat.loc[~df_concat['Прочие'].isna(), 'признак_Диагноза'] = 'Есть'

# %%
# df_concat.loc[df_concat['признак_Диагноза'].isna()]
# Out:
# Empty DataFrame
# Columns: [Дата_вкл_реестр, Пациент, ДР, Пол, Дата_признания, Текущий статус пациента, Дата_прекр, Филиал, Иногород, Диагноз, Дата_первых_сведений, Дата_выбытия, Возраст, Категория, Дети, Длителность_наблюдения, признак_Диагноза, Онкология, Неврология, Терапия, Педиатрия, Врожденные, ВИЧ, Психиатрия, Прочие]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# ### Признак

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Признак "КЛЮЧ"  <br>
# </b>            </div>

# %%
#  ----- Добавим УНИКАЛЬНЫЙ ключ ФИО+ДР - без пробелов ------------

df_concat['Ключ'] = df_concat['Пациент'].map(str) + (df_concat['ДР'].dt.date).map(str)
df_concat['Ключ'] = df_concat['Ключ'].str.lower()            # ---- все к нижнему регистру
df_concat['Ключ'] = df_concat['Ключ'].str.replace(' ', '')   # ---- пробелы долой 
# df_concat.shape
# -------- количество уникальных ------
# df_concat['Ключ'].unique().shape[0]

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Итоговый df с НЕПУСТЫМИ Дата_первых_сведений и положительной длительность. наблюдения или НЕЗАКРЫТОЙ длительностью наблюдения  <br>
# </b>            </div>

# %%
df_clr = df_concat.loc[ (~df_concat['Дата_первых_сведений'].isnull()) & ((df_concat['Длителность_наблюдения'] > '0 days') | (df_concat['Длителность_наблюдения'].isna()))]
df_clr.shape
# Out:
# (67311, 26)

# %%
# df_clr.loc[df_clr['Дети'].isna()]

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> => Основные вычисления  <br>
# </b>            </div>

# %%
date_start = '2022-01-01'
date_finish = '2023-01-01'

# %%
# ----------------------- функция расчета --------------

def calculate_data(df, date_start, date_finish, period_start, period_end):
    df_clr = df.copy()
    df_clr = df_clr.drop_duplicates()
    #     ---------------------------------------------------------------- ВЗРОСЛЫХ ----------------------------------------------------------
    # ------   ОНКО   ------
    vzros_onko = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] == 'Onko')                                                                  # ОНКО = ДА
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]
    
    # ------  НЕ ОНКО  ------
    vzros_ne_onko = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] != 'Onko')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]    
    
#     ---------УМЕР ОНКО ----------------
    vzros_onko_died = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] == 'Onko')                                                                  # ОНКО = ДА
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                          & ( df_clr['Текущий статус пациента'] == 'Умер')
        
                        ].shape[0]
    
#     ---------УМЕР НЕ ОНКО ----------------    
    vzros_ne_onko_died = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] != 'Onko')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                          & ( df_clr['Текущий статус пациента'] == 'Умер')
                        ].shape[0]    
     
    
#     ---------------------------------------------------------------------Дети ----------------------------
 # ------   ОНКО   ------
    deti_onko = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] == 'Onko')                                                                  # ОНКО = ДА
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]
    
 # ------   НЕ ОНКО   ------
    deti_ne_onko = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] != 'Onko')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]    
    #     --------------------------------------------------------УМЕРЛИ ----------------
    #     ---------УМЕР ОНКО ----------------
    deti_onko_died = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] == 'Onko')                                                                  # ОНКО = ДА
                          & ( ~(df_clr['Дети']).isna())                                                                        # Дети = НЕТ 
                          & ( df_clr['Текущий статус пациента'] == 'Умер')
        
                        ].shape[0]
    
#     ---------УМЕР НЕ ОНКО ----------------    
    deti_ne_onko_died = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] != 'Onko')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                       # Дети = НЕТ 
                          & ( df_clr['Текущий статус пациента'] == 'Умер')
                        ].shape[0]    
    
    
    
    return vzros_onko, vzros_onko_died, vzros_ne_onko, vzros_ne_onko_died, deti_onko, deti_onko_died, deti_ne_onko, deti_ne_onko_died

# %%
df_clr.columns
# Out:
# Index(['Дата_вкл_реестр', 'Пациент', 'ДР', 'Пол', 'Дата_признания',
#        'Текущий статус пациента', 'Дата_прекр', 'Филиал', 'Иногород',
#        'Диагноз', 'Дата_первых_сведений', 'Дата_выбытия', 'Возраст',
#        'Категория', 'Дети', 'Длителность_наблюдения', 'признак_Диагноза',
#        'Онкология', 'Неврология', 'Терапия', 'Педиатрия', 'Врожденные', 'ВИЧ',
#        'Психиатрия', 'Прочие', 'Ключ'],
#       dtype='object')

# %%
# ----------------------- функция расчета diagnoz --------------

def calculate_diagnoz(df, date_start, date_finish, period_start, period_end):
    df_clr = df.copy()
    df_clr = df_clr.drop_duplicates()
    #     ---------------------------------------------------------------- ВЗРОСЛЫХ ----------------------------------------------------------
    
    # ------  Терапия  ------
    vzros_terap = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Терапия'] == 'Терапия')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]    
    
    
       # ------  Неврология  ------
    vzros_nevrol = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Неврология'] == 'Неврология')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]     
    
         # ------  Психиатрия  ------
    vzros_psih = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Психиатрия'] == 'Психиатрия')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]       
    
          # ------  ВИЧ  ------
    vzros_vich = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['ВИЧ'] == 'ВИЧ')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]          
    
    
            # ------  proch------
    vzros_proch = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Прочие'] == 'Прочие')                                                                 # ОНКО = No
                          & ( (df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]            
    
    
    
#     ---------------------------------------------------------------------Дети ----------------------------
 
     # ------  Педиатрия  ------
    deti_pediatr = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Педиатрия'] == 'Педиатрия')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]    
    
    
       # ------  Неврология  ------
    deti_nevrol = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Неврология'] == 'Неврология')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]     
    
         # ------  Психиатрия  ------
    deti_psih = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Психиатрия'] == 'Психиатрия')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]       
    
          # ------  vrojden  ------
    deti_vrojden = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Врожденные'] == 'Врожденные')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]          
    
    
            # ------  proch------
    deti_proch = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Прочие'] == 'Прочие')                                                                 # ОНКО = No
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ].shape[0]               
    
 

    
    
    return     vzros_terap,  vzros_nevrol, vzros_psih, vzros_vich , vzros_proch,  deti_pediatr, deti_nevrol, deti_psih ,  deti_vrojden, deti_proch

# %%
date_start = '2022-01-01'
date_finish = '2023-01-01'
period_start = '180 days'
period_end = '360 days'

# period_start = '0 days'
# period_end = '30 days'

# period_start = '30 days'
# period_end = '90 days'

# period_start = '90 days'
# period_end = '180 days'

# period_start = '180 days'
# period_end = '360 days'

# period_start = '360 days'
# period_end = '60000 days'

new_data = calculate_data(df_clr, date_start, date_finish, period_start, period_end)
diagn = calculate_diagnoz(df_clr, date_start, date_finish, period_start, period_end)

print(f'Год------------------------------ {date_start}\n\
Период--------------------------- {period_start} - {period_end}\n\
ВЗРОСЛЫХ ОНКО пациентов в периоде------------- {new_data[0]} \n\
ВЗРОСЛЫХ ОНКО УМЕРЛО  ------------------------ {new_data[1]} \n\
ВЗРОСЛЫХ НЕ ОНКО пациентов  ------------------ {new_data[2]} \n\
----------------------------------------\n\
ВЗРОСЛЫХ терапия  ------------------ {diagn[0]} \n\
ВЗРОСЛЫХ неврология----------------- {diagn[1]} \n\
ВЗРОСЛЫХ психиатрия----------------- {diagn[2]} \n\
ВЗРОСЛЫХ ВИЧ-инфекц----------------- {diagn[3]} \n\
ВЗРОСЛЫХ прочие--------------------- {diagn[4]} \n\
----------------------------------------\n\
ВЗРОСЛЫХ НЕ ОНКО УМЕРЛО ---------------------- {new_data[3]} \n\
----------------------------------------\n\
ДЕТИ ОНКО пациентов в периоде----------------- {new_data[4]} \n\
ДЕТИ ОНКО УМЕРЛО  ---------------------------- {new_data[5]} \n\
ДЕТИ НЕ ОНКО пациентов  ---------------------- {new_data[6]} \n\
ДЕТИ педиатрия  ------------------ {diagn[5]} \n\
ДЕТИ неврология  ----------------- {diagn[6]} \n\
ДЕТИ психиатрия------------------- {diagn[7]} \n\
ДЕТИ врожденные ------------------- {diagn[8]} \n\
ДЕТИ прочие----------------------- {diagn[9]} \n\
----------------------------------------\n\
ДЕТИ НЕ ОНКО УМЕРЛО -------------------------- {new_data[7]} ')
print(new_data)
print('--'*50)
print('--'*50)
# Out:
# Год------------------------------ 2022-01-01
# Период--------------------------- 180 days - 360 days
# ВЗРОСЛЫХ ОНКО пациентов в периоде------------- 1403
# ВЗРОСЛЫХ ОНКО УМЕРЛО  ------------------------ 691
# ВЗРОСЛЫХ НЕ ОНКО пациентов  ------------------ 1631
# ----------------------------------------
# ВЗРОСЛЫХ терапия  ------------------ 1063
# ВЗРОСЛЫХ неврология----------------- 279
# ВЗРОСЛЫХ психиатрия----------------- 12
# ВЗРОСЛЫХ ВИЧ-инфекц----------------- 3
# ВЗРОСЛЫХ прочие--------------------- 273
# ----------------------------------------
# ВЗРОСЛЫХ НЕ ОНКО УМЕРЛО ---------------------- 493
# ----------------------------------------
# ДЕТИ ОНКО пациентов в периоде----------------- 9
# ДЕТИ ОНКО УМЕРЛО  ---------------------------- 4
# ДЕТИ НЕ ОНКО пациентов  ---------------------- 87
# ДЕТИ педиатрия  ------------------ 1
# ДЕТИ неврология  ----------------- 59
# ДЕТИ психиатрия------------------- 2
# ДЕТИ врожденные ------------------- 16
# ...

# %%
df_clr.describe()
# Out:
#             Возраст       Длителность_наблюдения
# count  67236.000000                        67311
# mean      71.876123  233 days 00:53:36.686722824
# std       14.802034  805 days 12:04:23.454285424
# min       -8.000000              1 days 00:00:00
# 25%       64.000000             12 days 00:00:00
# 50%       73.000000             44 days 00:00:00
# 75%       82.000000            193 days 00:00:00
# max      277.000000          66856 days 00:00:00

# %%
# df_clr_22.loc[ (df_clr_22['Длителность_наблюдения'] >  '3000 days')] 
# df_clr_22.loc[ (df_clr_22['Дата_выбытия'] >  '2023-03-10')]

# %%
date_finish = '2023-01-01'
date_start = '2022-01-01'
df_clr_22 = df_clr.loc[ 
                            (df_clr['Дата_первых_сведений'] < date_finish)                                                      # дата внесения в реестр - ранее date_start
                          & ( (df_clr['Дата_выбытия'].isnull())   | (df_clr['Дата_выбытия'] >= date_start) )                   # дата выбытия - еще не выбыл или дата выбытия - после date_start
                          & ((df_clr['Длителность_наблюдения'] <  '3000 days'))
                          # & ( (df_clr['Длителность_наблюдения'] > period_start) & (df_clr['Длителность_наблюдения'] <= period_end)) # длительность наблюдения - от 1 дня до 30 дней
                          & (  df_clr['Онкология'] == 'Onko')                                                                  # ОНКО = ДА
                          & ( ~(df_clr['Дети']).isna())                                                                         # Дети = НЕТ 
                        ]
df_clr_22.describe()
# Out:
#          Возраст       Длителность_наблюдения
# count  35.000000                           35
# mean    8.542857  392 days 03:25:42.857142856
# std     5.872883  609 days 19:14:15.279998088
# min     0.000000              2 days 00:00:00
# 25%     2.500000             48 days 00:00:00
# 50%     9.000000            157 days 00:00:00
# 75%    14.000000            331 days 00:00:00
# max    17.000000           2792 days 00:00:00

# %% [markdown]
# <hr>
#
# <font color= green size=10>__ВЫВОД РЕЗУЛЬТАТОВ__
# <hr>

# %%
from IPython.display import display_markdown

# //-----  госпитализаций из стационаов -------
df_gospit_22_sort

from_stac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'].isna()].shape[0]
un_pac_stac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'].isna()]['Ключ'].nunique()

iz_doma = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'Дом'].shape[0]
iz_dom_pac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'Дом']['Ключ'].nunique()


iz_CPP = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'CPP'].shape[0]
iz_CPP_pac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'CPP']['Ключ'].nunique()


a = 'Госпитализировано  в 2022 году:'

display_markdown(f'''
# {a}
| Параметр | Значение|
|---:|:-|
| Всего госпитал из стацион   | __{from_stac}__ |
| Пациентов   | {un_pac_stac} |
| Из дома   | {iz_doma} |
| iz_dom_pac   | {iz_dom_pac} |
| Из iz_CPP   | {iz_CPP} |
| iz_CPP   | {iz_CPP_pac} |

''', raw=True)

# %%
from IPython.display import display_markdown

# //-----  госпитализаций из стационаов -------
df_gospit_22_sort

from_stac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'].isna()].shape[0]
un_pac_stac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'].isna()]['Ключ'].nunique()

iz_doma = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'Дом'].shape[0]
iz_dom_pac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'Дом']['Ключ'].nunique()


iz_CPP = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'CPP'].shape[0]
iz_CPP_pac = df_gospit_22_sort.loc[df_gospit_22_sort['CPP'] == 'CPP']['Ключ'].nunique()


a = 'Госпитализировано  в 2022 году:'

display_markdown(f'''
# {a}
| Параметр | Значение|
|---:|:-|
| Всего госпитал из стацион   | __{from_stac}__ |
| Пациентов   | {un_pac_stac} |
| Из дома   | {iz_doma} |
| iz_dom_pac   | {iz_dom_pac} |
| Из iz_CPP   | {iz_CPP} |
| iz_CPP   | {iz_CPP_pac} |

''', raw=True)
