# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <!-- -info-warning-success-danger>   --> <font size=5>
# <b>
#     17..19 июля 2023<br>
#     расчет выдачи и возврата по пацентам <br>
#     </b>    </div>
# <hr>

# %%
import pandas as pd
import numpy as np
from IPython.display import display_markdown
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ####
# <div class="alert alert-block alert-success">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>подключаем выдачу
#     </b>    </div>
# <hr>

# %%
data_poluchenie = pd.read_csv('выдача_1с_все_pand.csv', delimiter=';', encoding='cp1251')
print(data_poluchenie.shape)
# Out:
# (21592, 7)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b>
#     Убираем лишние колонки для 605го и переименовываем
#     </b>
#     </div>
# <hr>

# %%
# ---------------------- функция преобразования к нижнему РЕГИСТРУ
def def_low(df):
    for i in df.columns:
        df[i] =  df[i].str.lower()
    return df

# %%
# как4ие есть колонки
# data_poluchenie.columns

# %%
# уберем лишние колонки
df_poluchenie_nomenk = data_poluchenie.copy()
df_poluchenie_nomenk = df_poluchenie_nomenk[['Пациент.ФИО', 'Пациент.Дата рождения', 'Пациент.Пол', 'Дата выдачи',
       'Оборудование.Номенклатура', 'Оборудование.Инвентарный номер',

                ]]
df_poluchenie_nomenk
# Out:
#                         Пациент.ФИО Пациент.Дата рождения Пациент.Пол  \
# 0             Шваков Макар Олегович            14.04.2014     Мужской
# 1         Мартынов Павел Дмитриевич            20.06.2010     Мужской
# 2       Дарчиева Кристина Арсеновна            15.03.2010     Женский
# 3      Бабаев Асланхон Акмалхонович            05.06.2019     Мужской
# 4       Горячев Владислав Сергеевич            28.12.2006     Мужской
# ...                             ...                   ...         ...
# 21587     Задкова Есения Евгеньевна            09.03.2016     Женский
# 21588     Задкова Есения Евгеньевна            09.03.2016     Женский
# 21589     Задкова Есения Евгеньевна            09.03.2016     Женский
# 21590     Задкова Есения Евгеньевна            09.03.2016     Женский
# 21591     Задкова Есения Евгеньевна            09.03.2016     Женский
#
#       Дата выдачи                          Оборудование.Номенклатура  \
# 0      14.04.2021                   Концентратор кислородный JAY-5A.
# 1      17.03.2021  Аппарат для удаления выделений из дыхательных ...
# 2      26.03.2021  Аппарат искуственной вентиляции легких Puritan...
# 3      31.03.2021                   Концентратор кислородный JAY-5A.
# 4      15.04.2021                     Аппарат НИВЛ WM 100 Prisma30ST
# ...           ...                                                ...
# 21587  17.07.2023  Отсасыватель хирургический электрический "Arme...
# 21588  17.07.2023  Отсасыватель хирургический электрический "Arme...
# 21589  17.07.2023  Отсасыватель хирургический электрический "Arme...
# 21590  17.07.2023  Отсасыватель хирургический электрический "Arme...
# 21591  17.07.2023  Отсасыватель хирургический электрический "Arme...
#
#       Оборудование.Инвентарный номер
# 0                  004410124-0003072
# 1                  004410124-0002667
# 2                  004410124-0003302
# 3                  004410124-0003073
# 4                   004410124-001791
# ...                              ...
# 21587              004410134-0083438
# 21588              004410134-0083438
# 21589              004410134-0083438
# 21590              004410134-0083438
# 21591              004410134-0083438
#
# [21592 rows x 6 columns]

# %%
df_poluchenie_nomenk = def_low(df_poluchenie_nomenk)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> Приведем ДАТЫ к фрмату ДАТА</b><br>
#             </div>

# %%
# ----------------форматнем дату к дате
df_poluchenie_nomenk['Пациент.Дата рождения'] = pd.to_datetime(df_poluchenie_nomenk['Пациент.Дата рождения'], dayfirst=True, errors = 'coerce').dt.normalize()
df_poluchenie_nomenk['Дата выдачи'] = pd.to_datetime(df_poluchenie_nomenk['Дата выдачи'], dayfirst=True, errors = 'coerce').dt.normalize()
df_poluchenie_nomenk
# Out:
#                         Пациент.ФИО Пациент.Дата рождения Пациент.Пол  \
# 0             шваков макар олегович            2014-04-14     мужской
# 1         мартынов павел дмитриевич            2010-06-20     мужской
# 2       дарчиева кристина арсеновна            2010-03-15     женский
# 3      бабаев асланхон акмалхонович            2019-06-05     мужской
# 4       горячев владислав сергеевич            2006-12-28     мужской
# ...                             ...                   ...         ...
# 21587     задкова есения евгеньевна            2016-03-09     женский
# 21588     задкова есения евгеньевна            2016-03-09     женский
# 21589     задкова есения евгеньевна            2016-03-09     женский
# 21590     задкова есения евгеньевна            2016-03-09     женский
# 21591     задкова есения евгеньевна            2016-03-09     женский
#
#       Дата выдачи                          Оборудование.Номенклатура  \
# 0      2021-04-14                   концентратор кислородный jay-5a.
# 1      2021-03-17  аппарат для удаления выделений из дыхательных ...
# 2      2021-03-26  аппарат искуственной вентиляции легких puritan...
# 3      2021-03-31                   концентратор кислородный jay-5a.
# 4      2021-04-15                     аппарат нивл wm 100 prisma30st
# ...           ...                                                ...
# 21587  2023-07-17  отсасыватель хирургический электрический "arme...
# 21588  2023-07-17  отсасыватель хирургический электрический "arme...
# 21589  2023-07-17  отсасыватель хирургический электрический "arme...
# 21590  2023-07-17  отсасыватель хирургический электрический "arme...
# 21591  2023-07-17  отсасыватель хирургический электрический "arme...
#
#       Оборудование.Инвентарный номер
# 0                  004410124-0003072
# 1                  004410124-0002667
# 2                  004410124-0003302
# 3                  004410124-0003073
# 4                   004410124-001791
# ...                              ...
# 21587              004410134-0083438
# 21588              004410134-0083438
# 21589              004410134-0083438
# 21590              004410134-0083438
# 21591              004410134-0083438
#
# [21592 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# Ключ            </div>

# %%
#  ----- Добавим УНИКАЛЬНЫЙ ключ ФИО+ДР - без пробелов ------------

df_poluchenie_nomenk['Ключ'] = df_poluchenie_nomenk['Пациент.ФИО'].map(str) + (df_poluchenie_nomenk['Пациент.Дата рождения'].dt.date).map(str) + df_poluchenie_nomenk['Оборудование.Инвентарный номер'].map(str)
df_poluchenie_nomenk['Ключ'] = df_poluchenie_nomenk['Ключ'].str.lower()            # ---- все к нижнему регистру
df_poluchenie_nomenk['Ключ'] = df_poluchenie_nomenk['Ключ'].str.replace(' ', '')   # ---- пробелы долой 
df_poluchenie_nomenk
# Out:
#                         Пациент.ФИО Пациент.Дата рождения Пациент.Пол  \
# 0             шваков макар олегович            2014-04-14     мужской
# 1         мартынов павел дмитриевич            2010-06-20     мужской
# 2       дарчиева кристина арсеновна            2010-03-15     женский
# 3      бабаев асланхон акмалхонович            2019-06-05     мужской
# 4       горячев владислав сергеевич            2006-12-28     мужской
# ...                             ...                   ...         ...
# 21587     задкова есения евгеньевна            2016-03-09     женский
# 21588     задкова есения евгеньевна            2016-03-09     женский
# 21589     задкова есения евгеньевна            2016-03-09     женский
# 21590     задкова есения евгеньевна            2016-03-09     женский
# 21591     задкова есения евгеньевна            2016-03-09     женский
#
#       Дата выдачи                          Оборудование.Номенклатура  \
# 0      2021-04-14                   концентратор кислородный jay-5a.
# 1      2021-03-17  аппарат для удаления выделений из дыхательных ...
# 2      2021-03-26  аппарат искуственной вентиляции легких puritan...
# 3      2021-03-31                   концентратор кислородный jay-5a.
# 4      2021-04-15                     аппарат нивл wm 100 prisma30st
# ...           ...                                                ...
# 21587  2023-07-17  отсасыватель хирургический электрический "arme...
# 21588  2023-07-17  отсасыватель хирургический электрический "arme...
# 21589  2023-07-17  отсасыватель хирургический электрический "arme...
# 21590  2023-07-17  отсасыватель хирургический электрический "arme...
# 21591  2023-07-17  отсасыватель хирургический электрический "arme...
#
#       Оборудование.Инвентарный номер  \
# 0                  004410124-0003072
# 1                  004410124-0002667
# 2                  004410124-0003302
# 3                  004410124-0003073
# 4                   004410124-001791
# ...                              ...
# 21587              004410134-0083438
# 21588              004410134-0083438
# 21589              004410134-0083438
# 21590              004410134-0083438
# 21591              004410134-0083438
#
#                                                     Ключ
# 0         шваковмакаролегович2014-04-14004410124-0003072
# 1      мартыновпавелдмитриевич2010-06-20004410124-000...
# 2      дарчиевакристинаарсеновна2010-03-15004410124-0...
# 3      бабаевасланхонакмалхонович2019-06-05004410124-...
# 4      горячеввладиславсергеевич2006-12-28004410124-0...
# ...                                                  ...
# 21587  задковаесенияевгеньевна2016-03-09004410134-008...
# 21588  задковаесенияевгеньевна2016-03-09004410134-008...
# 21589  задковаесенияевгеньевна2016-03-09004410134-008...
# 21590  задковаесенияевгеньевна2016-03-09004410134-008...
# 21591  задковаесенияевгеньевна2016-03-09004410134-008...
#
# [21592 rows x 7 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# Удалить повторы строк (одни и те же записи по выдаче)            </div>

# %%
df_poluchenie_nomenk = df_poluchenie_nomenk.drop_duplicates()

# %% [markdown]
# ####
# <div class="alert alert-block alert-success">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>подключаем возврат
#     </b>    </div>
# <hr>

# %%
data_vozvrat = pd.read_csv('возврат_1С_все_pand.csv', delimiter=';', encoding='cp1251')
print(data_vozvrat.shape)
# Out:
# (826, 5)

# %%
data_vozvrat = def_low(data_vozvrat)
# data_vozvrat
# Out:
#                                           Номенклатура  Инвентарный номер  \
# 0    аппарат искуственной вентиляции легких puritan...  004410124-0003335
# 1                     концентратор кислородный jay-5a.  004410124-0003081
# 2                       аппарат нивл wm 100 prisma30st   004410124-001815
# 3    аппарат искуственной вентиляции легких puritan...  004410124-0003266
# 4                       аппарат нивл wm 100 prisma30st   004410124-001812
# ..                                                 ...                ...
# 821  концентратор кислорода invacare, вариант испол...   004410124-001252
# 822  концентратор кислородный jay в следующем вариа...  004410134-0084495
# 823                    концентратор кислородный jay-10  004410124-0004299
# 824  концентратор кислородный jay в следующем вариа...  004410134-0084459
# 825  концентратор кислорода invacare, вариант испол...   004410124-000505
#
#              Ссылка.Дата                     Ссылка.Пациент  \
# 0    11.08.2021 12:00:00            петайкин иван борисович
# 1    11.08.2021 12:00:00            петайкин иван борисович
# 2    23.06.2021 13:48:15           дыров александр иванович
# 3    15.12.2022 13:26:07         чиркова ангелина сергеевна
# 4    26.05.2022 15:38:23              галан ринат андреевич
# ..                   ...                                ...
# 821  23.06.2023 18:14:06         боровков владимир иванович
# 822  10.07.2023 17:59:54         баренбойм елена викторовна
# 823  26.06.2023 12:17:58  подгорный александр александрович
# 824  28.06.2023 10:32:48             обухова ольга ивановна
# 825  05.07.2023 16:27:04         кочетков сергей николаевич
#
#     Ссылка.Пациент.Дата рождения
# 0                            NaN
# 1                            NaN
# 2                     11.08.2015
# 3                     02.01.2021
# 4                     20.04.2007
# ..                           ...
# 821                   14.12.1952
# 822                   02.04.1971
# 823                   24.11.1962
# 824                   03.11.1946
# 825                   06.01.1977
#
# [826 rows x 5 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b>
#     Убираем лишние колонки для 605го и переименовываем
#     </b>
#     </div>
# <hr>

# %%
# как4ие есть колонки
data_vozvrat.columns
# Out:
# Index(['Номенклатура', 'Инвентарный номер', 'Ссылка.Дата', 'Ссылка.Пациент',
#        'Ссылка.Пациент.Дата рождения'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <!-- <div class="alert alert-block alert-info">
# <div class="alert alert-block alert-warning">
# <div class="alert alert-block alert-success">
# <div class="alert alert-block alert-danger">
#      -->
# <font size=3>
# <b> Приведем ДАТЫ к фрмату ДАТА</b><br>
#             </div>

# %%
# ----------------форматнем дату к дате
data_vozvrat['Ссылка.Пациент.Дата рождения'] = pd.to_datetime(data_vozvrat['Ссылка.Пациент.Дата рождения'], dayfirst=True, errors = 'coerce').dt.normalize()
data_vozvrat['Ссылка.Дата'] = pd.to_datetime(data_vozvrat['Ссылка.Дата'], dayfirst=True, errors = 'coerce').dt.normalize()
data_vozvrat
# Out:
#                                           Номенклатура  Инвентарный номер  \
# 0    аппарат искуственной вентиляции легких puritan...  004410124-0003335
# 1                     концентратор кислородный jay-5a.  004410124-0003081
# 2                       аппарат нивл wm 100 prisma30st   004410124-001815
# 3    аппарат искуственной вентиляции легких puritan...  004410124-0003266
# 4                       аппарат нивл wm 100 prisma30st   004410124-001812
# ..                                                 ...                ...
# 821  концентратор кислорода invacare, вариант испол...   004410124-001252
# 822  концентратор кислородный jay в следующем вариа...  004410134-0084495
# 823                    концентратор кислородный jay-10  004410124-0004299
# 824  концентратор кислородный jay в следующем вариа...  004410134-0084459
# 825  концентратор кислорода invacare, вариант испол...   004410124-000505
#
#     Ссылка.Дата                     Ссылка.Пациент  \
# 0    2021-08-11            петайкин иван борисович
# 1    2021-08-11            петайкин иван борисович
# 2    2021-06-23           дыров александр иванович
# 3    2022-12-15         чиркова ангелина сергеевна
# 4    2022-05-26              галан ринат андреевич
# ..          ...                                ...
# 821  2023-06-23         боровков владимир иванович
# 822  2023-07-10         баренбойм елена викторовна
# 823  2023-06-26  подгорный александр александрович
# 824  2023-06-28             обухова ольга ивановна
# 825  2023-07-05         кочетков сергей николаевич
#
#     Ссылка.Пациент.Дата рождения
# 0                            NaT
# 1                            NaT
# 2                     2015-08-11
# 3                     2021-01-02
# 4                     2007-04-20
# ..                           ...
# 821                   1952-12-14
# 822                   1971-04-02
# 823                   1962-11-24
# 824                   1946-11-03
# 825                   1977-01-06
#
# [826 rows x 5 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# Ключ            </div>

# %%
#  ----- Добавим УНИКАЛЬНЫЙ ключ ФИО+ДР - без пробелов ------------

data_vozvrat['Ключ'] = data_vozvrat['Ссылка.Пациент'].map(str) + (data_vozvrat['Ссылка.Пациент.Дата рождения'].dt.date).map(str) + data_vozvrat['Инвентарный номер'].map(str)
data_vozvrat['Ключ'] = data_vozvrat['Ключ'].str.lower()            # ---- все к нижнему регистру
data_vozvrat['Ключ'] = data_vozvrat['Ключ'].str.replace(' ', '')   # ---- пробелы долой 
data_vozvrat
# Out:
#                                           Номенклатура  Инвентарный номер  \
# 0    аппарат искуственной вентиляции легких puritan...  004410124-0003335
# 1                     концентратор кислородный jay-5a.  004410124-0003081
# 2                       аппарат нивл wm 100 prisma30st   004410124-001815
# 3    аппарат искуственной вентиляции легких puritan...  004410124-0003266
# 4                       аппарат нивл wm 100 prisma30st   004410124-001812
# ..                                                 ...                ...
# 821  концентратор кислорода invacare, вариант испол...   004410124-001252
# 822  концентратор кислородный jay в следующем вариа...  004410134-0084495
# 823                    концентратор кислородный jay-10  004410124-0004299
# 824  концентратор кислородный jay в следующем вариа...  004410134-0084459
# 825  концентратор кислорода invacare, вариант испол...   004410124-000505
#
#     Ссылка.Дата                     Ссылка.Пациент  \
# 0    2021-08-11            петайкин иван борисович
# 1    2021-08-11            петайкин иван борисович
# 2    2021-06-23           дыров александр иванович
# 3    2022-12-15         чиркова ангелина сергеевна
# 4    2022-05-26              галан ринат андреевич
# ..          ...                                ...
# 821  2023-06-23         боровков владимир иванович
# 822  2023-07-10         баренбойм елена викторовна
# 823  2023-06-26  подгорный александр александрович
# 824  2023-06-28             обухова ольга ивановна
# 825  2023-07-05         кочетков сергей николаевич
#
#     Ссылка.Пациент.Дата рождения  \
# 0                            NaT
# 1                            NaT
# 2                     2015-08-11
# 3                     2021-01-02
# 4                     2007-04-20
# ..                           ...
# 821                   1952-12-14
# 822                   1971-04-02
# 823                   1962-11-24
# 824                   1946-11-03
# 825                   1977-01-06
#
#                                                   Ключ
# 0            петайкиниванборисовичnat004410124-0003335
# 1            петайкиниванборисовичnat004410124-0003081
# 2     дыровалександриванович2015-08-11004410124-001815
# 3    чирковаангелинасергеевна2021-01-02004410124-00...
# 4        галанринатандреевич2007-04-20004410124-001812
# ..                                                 ...
# 821  боровковвладимириванович1952-12-14004410124-00...
# 822  баренбоймеленавикторовна1971-04-02004410134-00...
# 823  подгорныйалександралександрович1962-11-2400441...
# 824    обуховаольгаивановна1946-11-03004410134-0084459
# 825  кочетковсергейниколаевич1977-01-06004410124-00...
#
# [826 rows x 6 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# СОЕДИНИМ ВЫДАЧУ и ВОЗВРАТ            </div>

# %%
df_poluch_vozvtat = df_poluchenie_nomenk.merge(data_vozvrat, how = 'left')
df_poluch_vozvtat
# Out:
#                        Пациент.ФИО Пациент.Дата рождения Пациент.Пол  \
# 0            шваков макар олегович            2014-04-14     мужской
# 1        мартынов павел дмитриевич            2010-06-20     мужской
# 2      дарчиева кристина арсеновна            2010-03-15     женский
# 3     бабаев асланхон акмалхонович            2019-06-05     мужской
# 4      горячев владислав сергеевич            2006-12-28     мужской
# ...                            ...                   ...         ...
# 5525  савельев владимир николаевич            1956-01-07     мужской
# 5526   афанасьева елена васильевна            1960-09-06     женский
# 5527     пуравецъ ксения андреевна            1989-07-18     женский
# 5528   баранова лидия владимировна            2012-01-16     женский
# 5529     задкова есения евгеньевна            2016-03-09     женский
#
#      Дата выдачи                          Оборудование.Номенклатура  \
# 0     2021-04-14                   концентратор кислородный jay-5a.
# 1     2021-03-17  аппарат для удаления выделений из дыхательных ...
# 2     2021-03-26  аппарат искуственной вентиляции легких puritan...
# 3     2021-03-31                   концентратор кислородный jay-5a.
# 4     2021-04-15                     аппарат нивл wm 100 prisma30st
# ...          ...                                                ...
# 5525  2023-07-17                                                NaN
# 5526  2023-07-17                                                NaN
# 5527  2023-07-17                                                NaN
# 5528         NaT                                                NaN
# 5529  2023-07-17  отсасыватель хирургический электрический "arme...
#
#      Оборудование.Инвентарный номер  \
# 0                 004410124-0003072
# 1                 004410124-0002667
# 2                 004410124-0003302
# 3                 004410124-0003073
# 4                  004410124-001791
# ...                             ...
# 5525                            NaN
# 5526                            NaN
# 5527                            NaN
# 5528                            NaN
# 5529              004410134-0083438
#
#                                                    Ключ  \
# 0        шваковмакаролегович2014-04-14004410124-0003072
# 1     мартыновпавелдмитриевич2010-06-20004410124-000...
# 2     дарчиевакристинаарсеновна2010-03-15004410124-0...
# 3     бабаевасланхонакмалхонович2019-06-05004410124-...
# 4     горячеввладиславсергеевич2006-12-28004410124-0...
# ...                                                 ...
# 5525            савельеввладимирниколаевич1956-01-07nan
# 5526             афанасьеваеленавасильевна1960-09-06nan
# 5527               пуравецъксенияандреевна1989-07-18nan
# 5528             барановалидиявладимировна2012-01-16nan
# 5529  задковаесенияевгеньевна2016-03-09004410134-008...
#
#                           Номенклатура  Инвентарный номер Ссылка.Дата  \
# 0                                  NaN                NaN         NaT
# 1                                  NaN                NaN         NaT
# 2                                  NaN                NaN         NaT
# 3     концентратор кислородный jay-5a.  004410124-0003073  2021-07-19
# 4                                  NaN                NaN         NaT
# ...                                ...                ...         ...
# 5525                               NaN                NaN         NaT
# 5526                               NaN                NaN         NaT
# 5527                               NaN                NaN         NaT
# 5528                               NaN                NaN         NaT
# 5529                               NaN                NaN         NaT
#
#                     Ссылка.Пациент Ссылка.Пациент.Дата рождения
# 0                              NaN                          NaT
# 1                              NaN                          NaT
# 2                              NaN                          NaT
# 3     бабаев асланхон акмалхонович                   2019-06-05
# 4                              NaN                          NaT
# ...                            ...                          ...
# 5525                           NaN                          NaT
# 5526                           NaN                          NaT
# 5527                           NaN                          NaT
# 5528                           NaN                          NaT
# 5529                           NaN                          NaT
#
# [5530 rows x 12 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# ПЕРЕИМЕНУЕМ           </div>

# %%
df_poluch_vozvtat.columns
# Out:
# Index(['Пациент.ФИО', 'Пациент.Дата рождения', 'Пациент.Пол', 'Дата выдачи',
#        'Оборудование.Номенклатура', 'Оборудование.Инвентарный номер', 'Ключ',
#        'Номенклатура', 'Инвентарный номер', 'Ссылка.Дата', 'Ссылка.Пациент',
#        'Ссылка.Пациент.Дата рождения'],
#       dtype='object')

# %%
df_poluch_vozvtat = df_poluch_vozvtat[[
    'Пациент.ФИО', 
    'Пациент.Дата рождения',
    'Пациент.Пол', 
    
       'Оборудование.Номенклатура',
    'Оборудование.Инвентарный номер',
   
       # 'Номенклатура',
    # 'Инвентарный номер',
    'Дата выдачи',
    'Ссылка.Дата',
     'Ключ',
    # 'Ссылка.Пациент',
       # 'Ссылка.Пациент.Дата рождения'
        
]]

# %%
#  переименуем покороче столбцы
df_poluch_vozvtat.rename(columns={'Пациент.ФИО': 'Пациент'}, inplace=True)
df_poluch_vozvtat.rename(columns={'Пациент.Дата рождения': 'ДР'}, inplace=True)
df_poluch_vozvtat.rename(columns={'Пациент.Пол': 'Пол'}, inplace=True)
df_poluch_vozvtat.rename(columns={'Оборудование.Номенклатура': 'Номенклатура'}, inplace=True)
df_poluch_vozvtat.rename(columns={'Оборудование.Инвентарный номер': 'Инвент_ном'}, inplace=True)
df_poluch_vozvtat.rename(columns={'Дата выдачи': 'Дата_выдачи'}, inplace=True)
df_poluch_vozvtat.rename(columns={'Ссылка.Дата': 'Дата_возвр'}, inplace=True)
# df_poluch_vozvtat.head(20)

# %%
df_poluch_vozvtat
# Out:
#                            Пациент         ДР      Пол  \
# 0            шваков макар олегович 2014-04-14  мужской
# 1        мартынов павел дмитриевич 2010-06-20  мужской
# 2      дарчиева кристина арсеновна 2010-03-15  женский
# 3     бабаев асланхон акмалхонович 2019-06-05  мужской
# 4      горячев владислав сергеевич 2006-12-28  мужской
# ...                            ...        ...      ...
# 5525  савельев владимир николаевич 1956-01-07  мужской
# 5526   афанасьева елена васильевна 1960-09-06  женский
# 5527     пуравецъ ксения андреевна 1989-07-18  женский
# 5528   баранова лидия владимировна 2012-01-16  женский
# 5529     задкова есения евгеньевна 2016-03-09  женский
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 5525                                                NaN                NaN
# 5526                                                NaN                NaN
# 5527                                                NaN                NaN
# 5528                                                NaN                NaN
# 5529  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#      Дата_выдачи Дата_возвр                                               Ключ
# 0     2021-04-14        NaT     шваковмакаролегович2014-04-14004410124-0003072
# 1     2021-03-17        NaT  мартыновпавелдмитриевич2010-06-20004410124-000...
# 2     2021-03-26        NaT  дарчиевакристинаарсеновна2010-03-15004410124-0...
# 3     2021-03-31 2021-07-19  бабаевасланхонакмалхонович2019-06-05004410124-...
# 4     2021-04-15        NaT  горячеввладиславсергеевич2006-12-28004410124-0...
# ...          ...        ...                                                ...
# 5525  2023-07-17        NaT            савельеввладимирниколаевич1956-01-07nan
# 5526  2023-07-17        NaT             афанасьеваеленавасильевна1960-09-06nan
# 5527  2023-07-17        NaT               пуравецъксенияандреевна1989-07-18nan
# 5528         NaT        NaT             барановалидиявладимировна2012-01-16nan
# 5529  2023-07-17        NaT  задковаесенияевгеньевна2016-03-09004410134-008...
#
# [5530 rows x 8 columns]

# %%
df_poluch_vozvtat = df_poluch_vozvtat.drop_duplicates()
df_poluch_vozvtat
# Out:
#                            Пациент         ДР      Пол  \
# 0            шваков макар олегович 2014-04-14  мужской
# 1        мартынов павел дмитриевич 2010-06-20  мужской
# 2      дарчиева кристина арсеновна 2010-03-15  женский
# 3     бабаев асланхон акмалхонович 2019-06-05  мужской
# 4      горячев владислав сергеевич 2006-12-28  мужской
# ...                            ...        ...      ...
# 5525  савельев владимир николаевич 1956-01-07  мужской
# 5526   афанасьева елена васильевна 1960-09-06  женский
# 5527     пуравецъ ксения андреевна 1989-07-18  женский
# 5528   баранова лидия владимировна 2012-01-16  женский
# 5529     задкова есения евгеньевна 2016-03-09  женский
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 5525                                                NaN                NaN
# 5526                                                NaN                NaN
# 5527                                                NaN                NaN
# 5528                                                NaN                NaN
# 5529  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#      Дата_выдачи Дата_возвр                                               Ключ
# 0     2021-04-14        NaT     шваковмакаролегович2014-04-14004410124-0003072
# 1     2021-03-17        NaT  мартыновпавелдмитриевич2010-06-20004410124-000...
# 2     2021-03-26        NaT  дарчиевакристинаарсеновна2010-03-15004410124-0...
# 3     2021-03-31 2021-07-19  бабаевасланхонакмалхонович2019-06-05004410124-...
# 4     2021-04-15        NaT  горячеввладиславсергеевич2006-12-28004410124-0...
# ...          ...        ...                                                ...
# 5525  2023-07-17        NaT            савельеввладимирниколаевич1956-01-07nan
# 5526  2023-07-17        NaT             афанасьеваеленавасильевна1960-09-06nan
# 5527  2023-07-17        NaT               пуравецъксенияандреевна1989-07-18nan
# 5528         NaT        NaT             барановалидиявладимировна2012-01-16nan
# 5529  2023-07-17        NaT  задковаесенияевгеньевна2016-03-09004410134-008...
#
# [5516 rows x 8 columns]

# %%
df_poluch_vozvtat_not_nul_nomenklat = df_poluch_vozvtat.loc[~df_poluch_vozvtat['Номенклатура'].isna()]
df_poluch_vozvtat_not_nul_nomenklat
# Out:
#                            Пациент         ДР      Пол  \
# 0            шваков макар олегович 2014-04-14  мужской
# 1        мартынов павел дмитриевич 2010-06-20  мужской
# 2      дарчиева кристина арсеновна 2010-03-15  женский
# 3     бабаев асланхон акмалхонович 2019-06-05  мужской
# 4      горячев владислав сергеевич 2006-12-28  мужской
# ...                            ...        ...      ...
# 5516    коваленко матвей сергеевич 2020-02-10  мужской
# 5518   медведев владимир зенонович 1953-01-10  мужской
# 5519    расторгуева елена ивановна 1964-06-16  женский
# 5524      агапов андрей васильевич 1962-03-10  мужской
# 5529     задкова есения евгеньевна 2016-03-09  женский
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 5516  аппарат искуственной вентиляции легких puritan...  004410124-0003331
# 5518  концентратор кислорода invacare, вариант испол...   004410124-000513
# 5519  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 5524  аппарат для лечения нарушений дыхания во сне w...  004410124-0006265
# 5529  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#      Дата_выдачи Дата_возвр                                               Ключ
# 0     2021-04-14        NaT     шваковмакаролегович2014-04-14004410124-0003072
# 1     2021-03-17        NaT  мартыновпавелдмитриевич2010-06-20004410124-000...
# 2     2021-03-26        NaT  дарчиевакристинаарсеновна2010-03-15004410124-0...
# 3     2021-03-31 2021-07-19  бабаевасланхонакмалхонович2019-06-05004410124-...
# 4     2021-04-15        NaT  горячеввладиславсергеевич2006-12-28004410124-0...
# ...          ...        ...                                                ...
# 5516  2023-07-14        NaT  коваленкоматвейсергеевич2020-02-10004410124-00...
# 5518  2023-07-14        NaT  медведеввладимирзенонович1953-01-10004410124-0...
# 5519  2023-07-15        NaT  расторгуеваеленаивановна1964-06-16004210124-00...
# 5524  2023-07-17        NaT  агаповандрейвасильевич1962-03-10004410124-0006265
# 5529  2023-07-17        NaT  задковаесенияевгеньевна2016-03-09004410134-008...
#
# [3045 rows x 8 columns]

# %% [markdown]
# ####
# <div class="alert alert-block alert-success">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>Данные по выдачам - возвратам из 1C
#     </b>    </div>
# <hr>

# %%
df_1c = df_poluch_vozvtat_not_nul_nomenklat.copy()

# %%
df_1c.to_excel('df_1c.xlsx')

# %% [markdown]
# ####
# <div class="alert alert-block alert-info">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>Подключение гугл-таблиц сбора даных о выдаче
#     </b>    </div>
# <hr>

# %%
data_df = pd.read_csv('Респираторка.csv', delimiter=';', encoding='cp1251')
data_df = def_low(data_df)
print(data_df.shape)
# Out:
# (12041, 10)

# %% [markdown]
# ####
# <div class="alert alert-block alert-warning">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>Первичное поступление на склад ВЫКИДЫВАЕМ!!!!
#     </b>    </div>
# <hr>

# %%
df_google = data_df.loc[data_df['Тип движения ТСР'] != 'первичное поступление на склад']
df_google.shape
# Out:
# (10040, 10)

# %%
# ЕЛГ нормализация дат
df_google['Дата рождения'] = pd.to_datetime(df_google['Дата рождения'], dayfirst=True, errors = 'coerce').dt.normalize()
df_google['Дата выдачи'] = pd.to_datetime(df_google['Дата выдачи'], dayfirst=True, errors = 'coerce').dt.normalize()
df_google['Дата возврата'] = pd.to_datetime(df_google['Дата возврата'], dayfirst=True, errors = 'coerce').dt.normalize()
df_google.head(3)
# Out:
#   Тип оборудования                                Единое наименование  \
# 1     концентратор  концентратор кислородный jay в следующем вариа...
# 2     концентратор  концентратор кислородный jay в следующем вариа...
# 3     концентратор  концентратор кислородный jay в следующем вариа...
#
#    Инвентарный номер  Тип движения ТСР      Фамилия      Имя     Отчество  \
# 1  004410124-0002849   выдано пациенту   степлякова    мария  григорьевна
# 2  004410124-0002849  возврат на склад   степлякова    мария  григорьевна
# 3  004410124-0002849   выдано пациенту  селиверстов  аркадий     иванович
#
#   Дата рождения Дата выдачи Дата возврата
# 1    1940-07-08  2021-04-24           NaT
# 2    1940-07-08  2021-04-24    2021-05-10
# 3    1946-03-25  2021-05-11           NaT

# %%
# --------- новый признак ПАЦИЕНТ (соединим фам им и отч) ------------
# df_google.loc[~df_google['Отчество'].isna(), 'Пациент' ] = df_google['Фамилия'] + ' ' +  df_google['Имя'] + ' ' + df_google['Отчество']
# df_google.loc[~df_google['Имя'].isna(), 'Пациент' ] = df_google['Фамилия'] 
# df_google.loc[df_google['Отчество'].isna(), 'Пациент' ] = df_google['Фамилия'] + ' ' +  df_google['Имя']
# df_google.head(3)

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# Ключ с инвентарым и датой выдачи           </div>

# %%
   #  ----- Добавим УНИКАЛЬНЫЙ ключ ФИО+ДР - без пробелов ------------
df_google['Ключ'] = df_google['Фамилия'] + (df_google['Дата рождения'].dt.date).map(str) + '-' + df_google['Инвентарный номер'] + '-' + (df_google['Дата выдачи'].dt.date).map(str) 
df_google['Ключ'] = df_google['Ключ'].str.lower()            # ---- все к нижнему регистру
df_google['Ключ'] = df_google['Ключ'].str.replace(' ', '')   # ---- пробелы долой 
df_google.head(3)
# Out:
#   Тип оборудования                                Единое наименование  \
# 1     концентратор  концентратор кислородный jay в следующем вариа...
# 2     концентратор  концентратор кислородный jay в следующем вариа...
# 3     концентратор  концентратор кислородный jay в следующем вариа...
#
#    Инвентарный номер  Тип движения ТСР      Фамилия      Имя     Отчество  \
# 1  004410124-0002849   выдано пациенту   степлякова    мария  григорьевна
# 2  004410124-0002849  возврат на склад   степлякова    мария  григорьевна
# 3  004410124-0002849   выдано пациенту  селиверстов  аркадий     иванович
#
#   Дата рождения Дата выдачи Дата возврата  \
# 1    1940-07-08  2021-04-24           NaT
# 2    1940-07-08  2021-04-24    2021-05-10
# 3    1946-03-25  2021-05-11           NaT
#
#                                                 Ключ
# 1  степлякова1940-07-08-004410124-0002849-2021-04-24
# 2  степлякова1940-07-08-004410124-0002849-2021-04-24
# 3  селиверстов1946-03-25-004410124-0002849-2021-0...

# %% [markdown]
# <div class="alert alert-block alert-warning"><font size=3>
# Датафрейм с непустой датой ВОЗВРАТА          </div>

# %%
df_google_vozvrat = df_google.loc[~df_google['Дата возврата'].isna()]
df_google_vozvrat
# Out:
#       Тип оборудования                                Единое наименование  \
# 2         концентратор  концентратор кислородный jay в следующем вариа...
# 4         концентратор  концентратор кислородный jay в следующем вариа...
# 6         концентратор  концентратор кислородный jay в следующем вариа...
# 8         концентратор  концентратор кислородный jay в следующем вариа...
# 12        концентратор  концентратор кислородный jay в следующем вариа...
# ...                ...                                                ...
# 11501     концентратор                  концентратор кислородный jay - 10
# 11530     концентратор                  концентратор кислородный jay - 10
# 11538     концентратор  концентратор кислородный jay в следующем вариа...
# 11542     концентратор  концентратор кислородный jay в следующем вариа...
# 11544     концентратор  концентратор кислорода invacare, вариант испол...
#
#        Инвентарный номер  Тип движения ТСР      Фамилия        Имя  \
# 2      004410124-0002849  возврат на склад   степлякова      мария
# 4      004410124-0002849  возврат на склад  селиверстов    аркадий
# 6      004410124-0002849  возврат на склад     никитина    татьяна
# 8      004410124-0002849  возврат на склад      спирина     ираида
# 12     004410124-0002850  возврат на склад     миронова  валентина
# ...                  ...               ...          ...        ...
# 11501  004410124-0003234  возврат на склад          жук    людмила
# 11530  004410124-0003223  возврат на склад      нигруца     хамдия
# 11538  004410134-0084489  возврат на склад      аксенов      борис
# 11542  004410134-0084495  возврат на склад    баренбойм      елена
# 11544   004410124-000515  возврат на склад       шибаев   владимир
#
#             Отчество Дата рождения Дата выдачи Дата возврата  \
# 2        григорьевна    1940-07-08  2021-04-24    2021-05-10
# 4           иванович    1946-03-25  2021-05-11    2021-09-19
# 6         николаевна    1940-06-11  2021-09-24    2021-10-20
# 8         васильевна    1938-09-24  2021-10-21    2021-10-26
# 12          ивановна    1948-01-16  2021-11-15    2022-04-24
# ...              ...           ...         ...           ...
# 11501  александровна    1968-09-18  2023-04-14    2023-07-10
# 11530            NaN    1952-06-07  2023-06-05    2023-07-06
# 11538     николаевич    1955-04-09  2023-05-04    2023-06-26
# 11542     викторовна    1971-04-02  2023-06-16    2023-07-11
# 11544     николаевич    1946-05-11  2023-06-05    2023-07-11
#
#                                                     Ключ
# 2      степлякова1940-07-08-004410124-0002849-2021-04-24
# 4      селиверстов1946-03-25-004410124-0002849-2021-0...
# 6        никитина1940-06-11-004410124-0002849-2021-09-24
# 8         спирина1938-09-24-004410124-0002849-2021-10-21
# 12       миронова1948-01-16-004410124-0002850-2021-11-15
# ...                                                  ...
# 11501         жук1968-09-18-004410124-0003234-2023-04-14
# 11530     нигруца1952-06-07-004410124-0003223-2023-06-05
# 11538     аксенов1955-04-09-004410134-0084489-2023-05-04
# 11542   баренбойм1971-04-02-004410134-0084495-2023-06-16
# 11544       шибаев1946-05-11-004410124-000515-2023-06-05
#
# [3529 rows x 11 columns]

# %%
# df_google_vozvrat[df_google_vozvrat.duplicated('Ключ', keep=False)].sort_values('Ключ')

# %% [markdown]
# <div class="alert alert-block alert-info"><font size=3>
# Уникальные записи с датой ВОЗВРАТА          </div>

# %%
# ----------------- удалим ПОВТОРЫ по строке КЛЮЧ с ВЫДАЧЕЙ НОМЕРА
df_google_vozvrat = df_google_vozvrat.drop_duplicates('Ключ')
df_google_vozvrat
# Out:
#       Тип оборудования                                Единое наименование  \
# 2         концентратор  концентратор кислородный jay в следующем вариа...
# 4         концентратор  концентратор кислородный jay в следующем вариа...
# 6         концентратор  концентратор кислородный jay в следующем вариа...
#
#        Инвентарный номер Тип движения ТСР      Фамилия       Имя     Отчество  \
# 1      004410124-0002849  выдано пациенту   степлякова     мария  григорьевна
# 3      004410124-0002849  выдано пациенту  селиверстов   аркадий     иванович
# 5      004410124-0002849  выдано пациенту     никитина   татьяна   николаевна
# 7      004410124-0002849  выдано пациенту      спирина    ираида   васильевна
# 9      004410124-0002849  выдано пациенту     бадамшин    сергей   чингисович
# ...                  ...              ...          ...       ...          ...
# 11553   004410124-000513  выдано пациенту     медведев  владимир    зенонович
# 11554  004210124-0000126  выдано пациенту  расторгуева     елена     ивановна
# 11555                б/н  выдано пациенту      матюшин    сергей     олегович
# 11556  004410124-0006370  выдано пациенту      матюшин    сергей     олегович
# 11557  004410134-0083438  выдано пациенту      задкова    есения   евгеньевна
#
#       Дата рождения Дата выдачи Дата возврата  \
# 1        1940-07-08  2021-04-24           NaT
# 3        1946-03-25  2021-05-11           NaT
# 5        1940-06-11  2021-09-24           NaT
# 7        1938-09-24  2021-10-21           NaT
# 9        1954-08-13  2021-10-27           NaT
# ...             ...         ...           ...
# 11553    1953-01-10  2023-07-14           NaT
# 11554    1946-06-16  2023-07-15           NaT
# 11555    2002-11-14  2023-07-17           NaT
# 11556    2002-11-14  2023-07-17           NaT
# 11557    2016-03-09  2023-07-17           NaT
#
#                                                     Ключ
# 1      степлякова1940-07-08-004410124-0002849-2021-04-24
# 3      селиверстов1946-03-25-004410124-0002849-2021-0...
# 5        никитина1940-06-11-004410124-0002849-2021-09-24
# 7         спирина1938-09-24-004410124-0002849-2021-10-21
# 9        бадамшин1954-08-13-004410124-0002849-2021-10-27
# ...                                                  ...
# 11553     медведев1953-01-10-004410124-000513-2023-07-14
# 11554  расторгуева1946-06-16-004210124-0000126-2023-0...
# 11555                   матюшин2002-11-14-б/н-2023-07-17
# 11556     матюшин2002-11-14-004410124-0006370-2023-07-17
# 11557     задкова2016-03-09-004410134-0083438-2023-07-17
#
# [6257 rows x 11 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning"><font size=3>
# ТОЛЬКО ПОВТОРНЫВЕ    </div>

# %%
# df_google_only_poluch[df_google_only_poluch.duplicated('Ключ', keep=False)].sort_values('Ключ')

# %% [markdown]
# <div class="alert alert-block alert-warning"><font size=3>
# создам df из ВОЗВРАТА только с данными   </div>

# %%
df_google_vozvrat.columns
# Out:
# Index(['Тип оборудования', 'Единое наименование', 'Инвентарный номер',
#        'Тип движения ТСР', 'Фамилия', 'Имя', 'Отчество', 'Дата рождения',
#        'Дата выдачи', 'Дата возврата', 'Ключ'],
#       dtype='object')

# %%
df_google_vozvrat_sh = df_google_vozvrat[[     'Дата выдачи', 'Дата возврата', 'Ключ']] 
df_google_vozvrat_sh
# Out:
#       Дата выдачи Дата возврата  \
# 2      2021-04-24    2021-05-10
# 4      2021-05-11    2021-09-19
# 6      2021-09-24    2021-10-20
# 8      2021-10-21    2021-10-26
# 12     2021-11-15    2022-04-24
# ...           ...           ...
# 11501  2023-04-14    2023-07-10
# 11530  2023-06-05    2023-07-06
# 11538  2023-05-04    2023-06-26
# 2       никитина1940-06-11-004410124-0002849-2021-09-24    2021-09-24
# 3        спирина1938-09-24-004410124-0002849-2021-10-21    2021-10-21
# 4       бадамшин1954-08-13-004410124-0002849-2021-10-27           NaT
# ...                                                 ...           ...
# 6252     медведев1953-01-10-004410124-000513-2023-07-14           NaT
# 6253  расторгуева1946-06-16-004210124-0000126-2023-0...           NaT
# 6254                   матюшин2002-11-14-б/н-2023-07-17           NaT
# 6255     матюшин2002-11-14-004410124-0006370-2023-07-17           NaT
# 6256     задкова2016-03-09-004410134-0083438-2023-07-17           NaT
#
#      Дата возврата_y
# 0         2021-05-10
# 1         2021-09-19
# 2         2021-10-20
# 3         2021-10-26
# 4                NaT
# ...              ...
# 6252             NaT
# 6253             NaT
# 6254             NaT
# 6255             NaT
# 6256             NaT
#
# [6257 rows x 13 columns]

# %%
# df_google_vozvrat_sh.loc[df_google_vozvrat_sh['Дата возврата'].isna()]

# %% [markdown]
# ####
# <div class="alert alert-block alert-success">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>ИТОГО ролучили результат по ВСЕМ выдачам-получениям ПРИБОРОВ с инвентарными номервми  </b>    </div>
# <hr>

# %%
df_google_poluch_vozvrat = df_google[[
# 'Тип оборудования', 
    'Единое наименование', 
    'Инвентарный номер',
       # 'Тип движения ТСР', 
    'Фамилия', 'Имя', 'Отчество', 'Дата рождения',
       'Дата выдачи_x', 
           'Дата возврата_y',
    # 'Дата возврата_x', 
    'Ключ', 
    # 'Дата выдачи_y',
]]
df_google_poluch_vozvrat
# Out:
#                                     Единое наименование  Инвентарный номер  \
# 0     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 1     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 2     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 3     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 4     концентратор кислородный jay в следующем вариа...  004410124-0002849
# ...                                                 ...                ...
# 6252  концентратор кислорода invacare, вариант испол...   004410124-000513
# 6253  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 6254  отсасыватель хирургический электрический "arme...                б/н
# 6255  пульсоксиметр (аппарат мониторинга пациента) n...  004410124-0006370
# 6256  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#           Фамилия       Имя     Отчество Дата рождения Дата выдачи_x  \
# 0      степлякова     мария  григорьевна    1940-07-08    2021-04-24
# 1     селиверстов   аркадий     иванович    1946-03-25    2021-05-11
# 2        никитина   татьяна   николаевна    1940-06-11    2021-09-24
# 3         спирина    ираида   васильевна    1938-09-24    2021-10-21
# 4        бадамшин    сергей   чингисович    1954-08-13    2021-10-27
# ...           ...       ...          ...           ...           ...
# 6252     медведев  владимир    зенонович    1953-01-10    2023-07-14
# 6253  расторгуева     елена     ивановна    1946-06-16    2023-07-15
# 6254      матюшин    сергей     олегович    2002-11-14    2023-07-17
# 6255      матюшин    сергей     олегович    2002-11-14    2023-07-17
# 6256      задкова    есения   евгеньевна    2016-03-09    2023-07-17
#
#      Дата возврата_y                                               Ключ
# 0         2021-05-10  степлякова1940-07-08-004410124-0002849-2021-04-24
# 1         2021-09-19  селиверстов1946-03-25-004410124-0002849-2021-0...
# 2         2021-10-20    никитина1940-06-11-004410124-0002849-2021-09-24
# 3         2021-10-26     спирина1938-09-24-004410124-0002849-2021-10-21
# 4                NaT    бадамшин1954-08-13-004410124-0002849-2021-10-27
# ...              ...                                                ...
# 6252             NaT     медведев1953-01-10-004410124-000513-2023-07-14
# 6253             NaT  расторгуева1946-06-16-004210124-0000126-2023-0...
# 6254             NaT                   матюшин2002-11-14-б/н-2023-07-17
# 6255             NaT     матюшин2002-11-14-004410124-0006370-2023-07-17
# 6256             NaT     задкова2016-03-09-004410134-0083438-2023-07-17
#
# [6257 rows x 9 columns]

# %% [markdown]
# ####
# <div class="alert alert-block alert-info">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>Соединим с выдачами из 1С  </b>    </div>
# <hr>

# %% [markdown]
# <div class="alert alert-block alert-info">
# df из 1С   </div>

# %%
df_1c = df_poluch_vozvtat_not_nul_nomenklat.copy()
df_1c['Источник'] = '1c'

# %%
df_1c = df_1c[['Пациент', 'ДР', 'Номенклатура', 'Инвент_ном', 'Дата_выдачи',
       'Дата_возвр', 'Ключ', 'Источник']]

# %%
# ------------------ Новый ключ --------------
df_1c['Ключ_2'] = df_1c['Пациент'].str.split(pat=' ', expand=True)[0] + '-' + df_1c['Инвент_ном'] + '-' + (df_1c['Дата_выдачи'].dt.date).map(str) + df_1c['Номенклатура']
df_1c
# Out:
#                            Пациент         ДР  \
# 0            шваков макар олегович 2014-04-14
# 1        мартынов павел дмитриевич 2010-06-20
# 2      дарчиева кристина арсеновна 2010-03-15
# 3     бабаев асланхон акмалхонович 2019-06-05
# 4      горячев владислав сергеевич 2006-12-28
# ...                            ...        ...
# 5516    коваленко матвей сергеевич 2020-02-10
# 5518   медведев владимир зенонович 1953-01-10
# 5519    расторгуева елена ивановна 1964-06-16
# 5524      агапов андрей васильевич 1962-03-10
# 5529     задкова есения евгеньевна 2016-03-09
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 5516  аппарат искуственной вентиляции легких puritan...  004410124-0003331
# 5518  концентратор кислорода invacare, вариант испол...   004410124-000513
# 5519  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 5524  аппарат для лечения нарушений дыхания во сне w...  004410124-0006265
# 5529  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#      Дата_выдачи Дата_возвр  \
# 0     2021-04-14        NaT
# 1     2021-03-17        NaT
# 2     2021-03-26        NaT
# 3     2021-03-31 2021-07-19
# 4     2021-04-15        NaT
# ...          ...        ...
# 5516  2023-07-14        NaT
# 5518  2023-07-14        NaT
# 5519  2023-07-15        NaT
# 5524  2023-07-17        NaT
# 5529  2023-07-17        NaT
#
#                                                    Ключ Источник  \
# 0        шваковмакаролегович2014-04-14004410124-0003072       1c
# 1     мартыновпавелдмитриевич2010-06-20004410124-000...       1c
# 2     дарчиевакристинаарсеновна2010-03-15004410124-0...       1c
# 3     бабаевасланхонакмалхонович2019-06-05004410124-...       1c
# 4     горячеввладиславсергеевич2006-12-28004410124-0...       1c
# ...                                                 ...      ...
# 5516  коваленкоматвейсергеевич2020-02-10004410124-00...       1c
# 5518  медведеввладимирзенонович1953-01-10004410124-0...       1c
# 5519  расторгуеваеленаивановна1964-06-16004210124-00...       1c
# 5524  агаповандрейвасильевич1962-03-10004410124-0006265       1c
# 5529  задковаесенияевгеньевна2016-03-09004410134-008...       1c
#
#                                                  Ключ_2
# 0     шваков-004410124-0003072-2021-04-14концентрато...
# 1     мартынов-004410124-0002667-2021-03-17аппарат д...
# 2     дарчиева-004410124-0003302-2021-03-26аппарат и...
# 3     бабаев-004410124-0003073-2021-03-31концентрато...
# 4     горячев-004410124-001791-2021-04-15аппарат нив...
# ...                                                 ...
# 5516  коваленко-004410124-0003331-2023-07-14аппарат ...
# 5518  медведев-004410124-000513-2023-07-14концентрат...
# 5519  расторгуева-004210124-0000126-2023-07-15аппара...
# 5524  агапов-004410124-0006265-2023-07-17аппарат для...
# 5529  задкова-004410134-0083438-2023-07-17отсасывате...
#
# [3045 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# df из ГУГЛ   </div>

# %%
df_gle = df_google_poluch_vozvrat.copy()
df_gle['Источник'] = 'goole'
df_gle
# Out:
#                                     Единое наименование  Инвентарный номер  \
# 0     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 1     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 2     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 3     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 4     концентратор кислородный jay в следующем вариа...  004410124-0002849
# ...                                                 ...                ...
# 6252  концентратор кислорода invacare, вариант испол...   004410124-000513
# 6253  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 6254  отсасыватель хирургический электрический "arme...                б/н
# 6255  пульсоксиметр (аппарат мониторинга пациента) n...  004410124-0006370
# 6256  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#           Фамилия       Имя     Отчество Дата рождения Дата выдачи_x  \
# 0      степлякова     мария  григорьевна    1940-07-08    2021-04-24
# 1     селиверстов   аркадий     иванович    1946-03-25    2021-05-11
# 2        никитина   татьяна   николаевна    1940-06-11    2021-09-24
# 3         спирина    ираида   васильевна    1938-09-24    2021-10-21
# 4        бадамшин    сергей   чингисович    1954-08-13    2021-10-27
# ...           ...       ...          ...           ...           ...
# 6252     медведев  владимир    зенонович    1953-01-10    2023-07-14
# 6253  расторгуева     елена     ивановна    1946-06-16    2023-07-15
# 6254      матюшин    сергей     олегович    2002-11-14    2023-07-17
# 6255      матюшин    сергей     олегович    2002-11-14    2023-07-17
# 6256      задкова    есения   евгеньевна    2016-03-09    2023-07-17
#
#      Дата возврата_y                                               Ключ  \
# 0         2021-05-10  степлякова1940-07-08-004410124-0002849-2021-04-24
# 1         2021-09-19  селиверстов1946-03-25-004410124-0002849-2021-0...
# 2         2021-10-20    никитина1940-06-11-004410124-0002849-2021-09-24
# 3         2021-10-26     спирина1938-09-24-004410124-0002849-2021-10-21
# 4                NaT    бадамшин1954-08-13-004410124-0002849-2021-10-27
# ...              ...                                                ...
# 6252             NaT     медведев1953-01-10-004410124-000513-2023-07-14
# 6253             NaT  расторгуева1946-06-16-004210124-0000126-2023-0...
# 6254             NaT                   матюшин2002-11-14-б/н-2023-07-17
# 6255             NaT     матюшин2002-11-14-004410124-0006370-2023-07-17
# 6256             NaT     задкова2016-03-09-004410134-0083438-2023-07-17
#
#      Источник
# 0       goole
# 1       goole
# 2       goole
# 3       goole
# 4       goole
# ...       ...
# 6252    goole
# 6253    goole
# 6254    goole
# 6255    goole
# 6256    goole
#
# [6257 rows x 10 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# приведем df из ГУГЛ к такому же виду как и 1С   </div>

# %%
#  переименуем столбцы
df_gle.rename(columns={'Дата рождения': 'ДР'}, inplace=True)
df_gle.rename(columns={'Единое наименование': 'Номенклатура'}, inplace=True)
df_gle.rename(columns={'Инвентарный номер': 'Инвент_ном'}, inplace=True)
df_gle.rename(columns={'Дата выдачи_x': 'Дата_выдачи'}, inplace=True)
df_gle.rename(columns={'Дата возврата_y': 'Дата_возвр'}, inplace=True)
df_gle
# Out:
#                                            Номенклатура         Инвент_ном  \
# 0     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 1     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 2     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 3     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 4     концентратор кислородный jay в следующем вариа...  004410124-0002849
# ...                                                 ...                ...
# 6252  концентратор кислорода invacare, вариант испол...   004410124-000513
# 6253  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 6254  отсасыватель хирургический электрический "arme...                б/н
# 6255  пульсоксиметр (аппарат мониторинга пациента) n...  004410124-0006370
# 6256  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#           Фамилия       Имя     Отчество         ДР Дата_выдачи Дата_возвр  \
# 0      степлякова     мария  григорьевна 1940-07-08  2021-04-24 2021-05-10
# 1     селиверстов   аркадий     иванович 1946-03-25  2021-05-11 2021-09-19
# 2        никитина   татьяна   николаевна 1940-06-11  2021-09-24 2021-10-20
# 3         спирина    ираида   васильевна 1938-09-24  2021-10-21 2021-10-26
# 4        бадамшин    сергей   чингисович 1954-08-13  2021-10-27        NaT
# ...           ...       ...          ...        ...         ...        ...
# 6252     медведев  владимир    зенонович 1953-01-10  2023-07-14        NaT
# 6253  расторгуева     елена     ивановна 1946-06-16  2023-07-15        NaT
# 6254      матюшин    сергей     олегович 2002-11-14  2023-07-17        NaT
# 6255      матюшин    сергей     олегович 2002-11-14  2023-07-17        NaT
# 6256      задкова    есения   евгеньевна 2016-03-09  2023-07-17        NaT
#
#                                                    Ключ Источник
# 0     степлякова1940-07-08-004410124-0002849-2021-04-24    goole
# 1     селиверстов1946-03-25-004410124-0002849-2021-0...    goole
# 2       никитина1940-06-11-004410124-0002849-2021-09-24    goole
# 3        спирина1938-09-24-004410124-0002849-2021-10-21    goole
# 4       бадамшин1954-08-13-004410124-0002849-2021-10-27    goole
# ...                                                 ...      ...
# 6252     медведев1953-01-10-004410124-000513-2023-07-14    goole
# 6253  расторгуева1946-06-16-004210124-0000126-2023-0...    goole
# 6254                   матюшин2002-11-14-б/н-2023-07-17    goole
# 6255     матюшин2002-11-14-004410124-0006370-2023-07-17    goole
# 6256     задкова2016-03-09-004410134-0083438-2023-07-17    goole
#
# [6257 rows x 10 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# # -------------- создадим поле ПАЦИЕНТ -------  </div>

# %%
# --------- новый признак ПАЦИЕНТ (соединим фам им и отч) ------------
# data_df.loc[~data_df['Отчество'].isna(), 'Пациент' ] = data_df['Фамилия'] + ' ' +  data_df['Имя'] + ' ' + data_df['Отчество']
df_gle.loc[
      (~df_gle['Фамилия'].isna())
    & (~df_gle['Имя'].isna())
    & (~df_gle['Отчество'].isna())
                                     , 'Пациент' ] = df_gle['Фамилия'] + ' ' +  df_gle['Имя'] + ' ' + df_gle['Отчество']

df_gle.loc[
      (df_gle['Фамилия'].isna())
    & (~df_gle['Имя'].isna())
    & (~df_gle['Отчество'].isna())
                                     , 'Пациент' ] = '-' + ' ' +  df_gle['Имя'] + ' ' + df_gle['Отчество']
df_gle.loc[
      (~df_gle['Фамилия'].isna())
    & (df_gle['Имя'].isna())
    & (~df_gle['Отчество'].isna())
                                     , 'Пациент' ] = df_gle['Фамилия'] + ' ' + df_gle['Отчество']

df_gle.loc[
      (~df_gle['Фамилия'].isna())
    & (~df_gle['Имя'].isna())
    & (df_gle['Отчество'].isna())
                                     , 'Пациент' ] = df_gle['Фамилия'] + ' ' +  df_gle['Имя'] 

df_gle.loc[
      (~df_gle['Фамилия'].isna())
    & (df_gle['Имя'].isna())
    & (df_gle['Отчество'].isna())
                                     , 'Пациент' ] = df_gle['Фамилия'] 

df_gle.loc[
      (df_gle['Фамилия'].isna())
    & (df_gle['Имя'].isna())
    & (df_gle['Отчество'].isna())
                                     , 'Пациент' ] = '-'

df_gle
# Out:
#                                            Номенклатура         Инвент_ном  \
# 0     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 1     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 2     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 3     концентратор кислородный jay в следующем вариа...  004410124-0002849
# 4     концентратор кислородный jay в следующем вариа...  004410124-0002849
# ...                                                 ...                ...
# 6252  концентратор кислорода invacare, вариант испол...   004410124-000513
# 6253  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 6254  отсасыватель хирургический электрический "arme...                б/н
# 6255  пульсоксиметр (аппарат мониторинга пациента) n...  004410124-0006370
# 6256  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#           Фамилия       Имя     Отчество         ДР Дата_выдачи Дата_возвр  \
# 0      степлякова     мария  григорьевна 1940-07-08  2021-04-24 2021-05-10
# 1     селиверстов   аркадий     иванович 1946-03-25  2021-05-11 2021-09-19
# 2        никитина   татьяна   николаевна 1940-06-11  2021-09-24 2021-10-20
# 3         спирина    ираида   васильевна 1938-09-24  2021-10-21 2021-10-26
# 4        бадамшин    сергей   чингисович 1954-08-13  2021-10-27        NaT
# ...           ...       ...          ...        ...         ...        ...
# 6252     медведев  владимир    зенонович 1953-01-10  2023-07-14        NaT
# 6253  расторгуева     елена     ивановна 1946-06-16  2023-07-15        NaT
# 6254      матюшин    сергей     олегович 2002-11-14  2023-07-17        NaT
# 6255      матюшин    сергей     олегович 2002-11-14  2023-07-17        NaT
# 6256      задкова    есения   евгеньевна 2016-03-09  2023-07-17        NaT
#
#                                                    Ключ Источник  \
# 0     степлякова1940-07-08-004410124-0002849-2021-04-24    goole
# 1     селиверстов1946-03-25-004410124-0002849-2021-0...    goole
# 2       никитина1940-06-11-004410124-0002849-2021-09-24    goole
# 3        спирина1938-09-24-004410124-0002849-2021-10-21    goole
# 4       бадамшин1954-08-13-004410124-0002849-2021-10-27    goole
# ...                                                 ...      ...
# 6252     медведев1953-01-10-004410124-000513-2023-07-14    goole
# 6253  расторгуева1946-06-16-004210124-0000126-2023-0...    goole
# 6254                   матюшин2002-11-14-б/н-2023-07-17    goole
# 6255     матюшин2002-11-14-004410124-0006370-2023-07-17    goole
# 6256     задкова2016-03-09-004410134-0083438-2023-07-17    goole
#
#                            Пациент
# 0     степлякова мария григорьевна
# 1     селиверстов аркадий иванович
# 2      никитина татьяна николаевна
# 3        спирина ираида васильевна
# 4       бадамшин сергей чингисович
# ...                            ...
# 6252   медведев владимир зенонович
# 6253    расторгуева елена ивановна
# 6254       матюшин сергей олегович
# 6255       матюшин сергей олегович
# 6256     задкова есения евгеньевна
#
# [6257 rows x 11 columns]

# %%
# ------------------ Новый ключ --------------
df_gle['Ключ_2'] = df_gle['Пациент'].str.split(pat=' ', expand=True)[0] + '-' + df_gle['Инвент_ном'] + '-' + (df_gle['Дата_выдачи'].dt.date).map(str)+ df_gle['Номенклатура']
df_gle
# Out:
#                                            Номенклатура         Инвент_ном  \
# 0     концентратор кислородный jay в следующем вариа...  004410124-0002849
#
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 5516  аппарат искуственной вентиляции легких puritan...  004410124-0003331
# 5518  концентратор кислорода invacare, вариант испол...   004410124-000513
# 5519  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 5524  аппарат для лечения нарушений дыхания во сне w...  004410124-0006265
# 5529  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#      Дата_выдачи Дата_возвр  \
# 0     2021-04-14        NaT
# 1     2021-03-17        NaT
# 2     2021-03-26        NaT
# 3     2021-03-31 2021-07-19
# 4     2021-04-15        NaT
# ...          ...        ...
# 5516  2023-07-14        NaT
# 5518  2023-07-14        NaT
# 5519  2023-07-15        NaT
# 5524  2023-07-17        NaT
# 5529  2023-07-17        NaT
#
#                                                    Ключ Источник  \
# 0        шваковмакаролегович2014-04-14004410124-0003072       1c
# 1     мартыновпавелдмитриевич2010-06-20004410124-000...       1c
# 2     дарчиевакристинаарсеновна2010-03-15004410124-0...       1c
# 3     бабаевасланхонакмалхонович2019-06-05004410124-...       1c
# 4     горячеввладиславсергеевич2006-12-28004410124-0...       1c
# ...                                                 ...      ...
# 5516  коваленкоматвейсергеевич2020-02-10004410124-00...       1c
# 5518  медведеввладимирзенонович1953-01-10004410124-0...       1c
# 5519  расторгуеваеленаивановна1964-06-16004210124-00...       1c
# 5524  агаповандрейвасильевич1962-03-10004410124-0006265       1c
# 5529  задковаесенияевгеньевна2016-03-09004410134-008...       1c
#
#                                                  Ключ_2
# 0     шваков-004410124-0003072-2021-04-14концентрато...
# 1     мартынов-004410124-0002667-2021-03-17аппарат д...
# 2     дарчиева-004410124-0003302-2021-03-26аппарат и...
# 3     бабаев-004410124-0003073-2021-03-31концентрато...
# 4     горячев-004410124-001791-2021-04-15аппарат нив...
# ...                                                 ...
# 5516  коваленко-004410124-0003331-2023-07-14аппарат ...
# 5518  медведев-004410124-000513-2023-07-14концентрат...
# 5519  расторгуева-004210124-0000126-2023-07-15аппара...
# 5524  агапов-004410124-0006265-2023-07-17аппарат для...
# 5529  задкова-004410134-0083438-2023-07-17отсасывате...
#
# [3045 rows x 9 columns]

# %% [markdown]
# ####
# <div class="alert alert-block alert-success">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>Соединяем 1С и Гугл датафреймы  </b>    </div>
# <hr>

# %%
df_1c = df_1c.drop_duplicates('Ключ_2')
df_1c.shape
# Out:
# (3031, 9)

# %%
df_gle = df_gle.drop_duplicates('Ключ_2')
df_gle.shape
# Out:
# (6254, 9)

# %%
df_unit = pd.concat([df_1c, df_gle])
df_unit
# Out:
#                            Пациент         ДР  \
# 0            шваков макар олегович 2014-04-14
# 1        мартынов павел дмитриевич 2010-06-20
# 2      дарчиева кристина арсеновна 2010-03-15
# 3     бабаев асланхон акмалхонович 2019-06-05
# 4      горячев владислав сергеевич 2006-12-28
# ...                            ...        ...
# 6252   медведев владимир зенонович 1953-01-10
# 6253    расторгуева елена ивановна 1946-06-16
# 6254       матюшин сергей олегович 2002-11-14
# 6255       матюшин сергей олегович 2002-11-14
# 6256     задкова есения евгеньевна 2016-03-09
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 6252  концентратор кислорода invacare, вариант испол...   004410124-000513
# 6253  аппарат искусственной вентиляции легких для пр...  004210124-0000126
# 6254  отсасыватель хирургический электрический "arme...                б/н
# 6255  пульсоксиметр (аппарат мониторинга пациента) n...  004410124-0006370
# 6256  отсасыватель хирургический электрический "arme...  004410134-0083438
#
#      Дата_выдачи Дата_возвр  \
# 0     2021-04-14        NaT
# 1     2021-03-17        NaT
# 2     2021-03-26        NaT
# 3     2021-03-31 2021-07-19
# 4     2021-04-15        NaT
# ...          ...        ...
# 6252  2023-07-14        NaT
# 6253  2023-07-15        NaT
# 6254  2023-07-17        NaT
# 6255  2023-07-17        NaT
# 6256  2023-07-17        NaT
#
#                                                    Ключ Источник  \
# 0        шваковмакаролегович2014-04-14004410124-0003072       1c
# 1     мартыновпавелдмитриевич2010-06-20004410124-000...       1c
# 2     дарчиевакристинаарсеновна2010-03-15004410124-0...       1c
# 3     бабаевасланхонакмалхонович2019-06-05004410124-...       1c
# 4     горячеввладиславсергеевич2006-12-28004410124-0...       1c
# ...                                                 ...      ...
# 6252     медведев1953-01-10-004410124-000513-2023-07-14    goole
# 6253  расторгуева1946-06-16-004210124-0000126-2023-0...    goole
# 6254                   матюшин2002-11-14-б/н-2023-07-17    goole
# 6255     матюшин2002-11-14-004410124-0006370-2023-07-17    goole
# 6256     задкова2016-03-09-004410134-0083438-2023-07-17    goole
#
#                                                  Ключ_2
# 0     шваков-004410124-0003072-2021-04-14концентрато...
# 1     мартынов-004410124-0002667-2021-03-17аппарат д...
# 2     дарчиева-004410124-0003302-2021-03-26аппарат и...
# 3     бабаев-004410124-0003073-2021-03-31концентрато...
# 4     горячев-004410124-001791-2021-04-15аппарат нив...
# ...                                                 ...
# 6252  медведев-004410124-000513-2023-07-14концентрат...
# 6253  расторгуева-004210124-0000126-2023-07-15аппара...
# 6254  матюшин-б/н-2023-07-17отсасыватель хирургическ...
# 6255  матюшин-004410124-0006370-2023-07-17пульсоксим...
# 6256  задкова-004410134-0083438-2023-07-17отсасывате...
#
# [9285 rows x 9 columns]

# %%
# df_unit[df_unit.duplicated('Ключ_2', keep=False)].sort_values('Ключ_2')
df_unit.shape[0]
# Out:
# 9285

# %%
# -------------- УДАЛИМ ДУБЛИКАТЫ объедиенного ДАТАФРЕЙМА 1С и ГУГЛ
df_unit = df_unit.drop_duplicates('Ключ_2')
df_unit
# Out:
#                            Пациент         ДР  \
# 0            шваков макар олегович 2014-04-14
# 1        мартынов павел дмитриевич 2010-06-20
# 2      дарчиева кристина арсеновна 2010-03-15
# 3     бабаев асланхон акмалхонович 2019-06-05
# 4      горячев владислав сергеевич 2006-12-28
# ...                            ...        ...
# 6246    колунов алексей степанович 1935-12-05
# 6249    коваленко матвей сергеевич 2020-02-10
# 6250    коваленко матвей сергеевич 2020-02-10
# 6254       матюшин сергей олегович 2002-11-14
# 6255       матюшин сергей олегович 2002-11-14
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
# 6246  концентратор кислородный jay в следующем вариа...  004410134-0081611
# 6249  аппарат искусственной вентиляции легких purita...  004410124-0003331
# 6250  подставка-держатель для аппарата ивл puritan b...  004410124-0005914
# 6254  отсасыватель хирургический электрический "arme...                б/н
# 6255  пульсоксиметр (аппарат мониторинга пациента) n...  004410124-0006370
#
#      Дата_выдачи Дата_возвр  \
# 0     2021-04-14        NaT
# 1     2021-03-17        NaT
# 2     2021-03-26        NaT
# 3     2021-03-31 2021-07-19
# 4     2021-04-15        NaT
# ...          ...        ...
# 6246  2023-07-13        NaT
# 6249  2023-07-14        NaT
# 6250  2023-07-14        NaT
# 6254  2023-07-17        NaT
# 6255  2023-07-17        NaT
#
#                                                    Ключ Источник  \
# 0        шваковмакаролегович2014-04-14004410124-0003072       1c
# 1     мартыновпавелдмитриевич2010-06-20004410124-000...       1c
# 2     дарчиевакристинаарсеновна2010-03-15004410124-0...       1c
# 3     бабаевасланхонакмалхонович2019-06-05004410124-...       1c
# 4     горячеввладиславсергеевич2006-12-28004410124-0...       1c
# ...                                                 ...      ...
# 6246     колунов1935-12-05-004410134-0081611-2023-07-13    goole
# 6249   коваленко2020-02-10-004410124-0003331-2023-07-14    goole
# 6250   коваленко2020-02-10-004410124-0005914-2023-07-14    goole
# 6254                   матюшин2002-11-14-б/н-2023-07-17    goole
# 6255     матюшин2002-11-14-004410124-0006370-2023-07-17    goole
#
#                                                  Ключ_2
# 0     шваков-004410124-0003072-2021-04-14концентрато...
# 1     мартынов-004410124-0002667-2021-03-17аппарат д...
# 2     дарчиева-004410124-0003302-2021-03-26аппарат и...
# 3     бабаев-004410124-0003073-2021-03-31концентрато...
# 4     горячев-004410124-001791-2021-04-15аппарат нив...
# ...                                                 ...
# 6246  колунов-004410134-0081611-2023-07-13концентрат...
# 6249  коваленко-004410124-0003331-2023-07-14аппарат ...
# 6250  коваленко-004410124-0005914-2023-07-14подставк...
# 6254  матюшин-б/н-2023-07-17отсасыватель хирургическ...
# 6255  матюшин-004410124-0006370-2023-07-17пульсоксим...
#
# [8023 rows x 9 columns]

# %%
df_unit.loc[~df_unit['Инвент_ном'].str.contains('-') == True]
# Out:
#                               Пациент         ДР  \
# 180       петрова виктория леонидовна 1969-09-09
# 256      куличихина софия григорьевна 2007-12-06
# 381      борикова евгения анатольевна 1936-02-18
# 428        батюшков валерий борисович 1958-01-01
# 436          бегинин алексей иванович 1977-08-22
# ...                               ...        ...
# 6142       наумова галина афанасьевна 1930-06-25
# 6143      петухов виктор владимирович 1939-05-22
# 6174  александров никита владимирович 2002-11-19
# 6197       коваленко матвей сергеевич 2020-02-10
# 6254          матюшин сергей олегович 2002-11-14
#
#                                            Номенклатура Инвент_ном  \
# 180        пульсоксиметр, модель м70в (взрослый размер)        б/н
# 256               отсасыватель хирургический аrmed 7е-а         00
# 381               отсасыватель хирургический аrmed 7е-а         00
# 428               матрас противопролежневый (ячеистый).         00
# 436               отсасыватель хирургический аrmed 7е-а        б/н
# ...                                                 ...        ...
# 6142  отсасыватель хирургический электрический "arme...        б/н
# 6143  отсасыватель хирургический электрический "arme...        б/н
# 6174  отсасыватель хирургический электрический "arme...        б/н
# 6197  штатив медицинский для вливаний пятиопорный, м...        б/н
# 6254  отсасыватель хирургический электрический "arme...        б/н
#
#      Дата_выдачи Дата_возвр                                    Ключ Источник  \
# 180   2023-01-31        NaT  петровавикториялеонидовна1969-09-09б/н       1c
# 256   2021-12-22        NaT  куличихинасофиягригорьевна2007-12-0600       1c
# 381   2021-12-29 2022-05-19  бориковаевгенияанатольевна1936-02-1800       1c
# 428   2022-06-03        NaT    батюшковвалерийборисович1958-01-0100       1c
# 436   2021-12-23        NaT     бегининалексейиванович1977-08-22б/н       1c
# ...          ...        ...                                     ...      ...
# 6142  2023-07-04        NaT        наумова1930-06-25-б/н-2023-07-04    goole
# 6143  2023-07-03        NaT        петухов1939-05-22-б/н-2023-07-03    goole
# 6174  2023-06-21        NaT    александров2002-11-19-б/н-2023-06-21    goole
# 6197  2023-07-07        NaT      коваленко2020-02-10-б/н-2023-07-07    goole
# 6254  2023-07-17        NaT        матюшин2002-11-14-б/н-2023-07-17    goole
#
#                                                  Ключ_2
# 180   петрова-б/н-2023-01-31пульсоксиметр, модель м7...
# 256   куличихина-00-2021-12-22отсасыватель хирургиче...
# 381   борикова-00-2021-12-29отсасыватель хирургическ...
# 428   батюшков-00-2022-06-03матрас противопролежневы...
# 436   бегинин-б/н-2021-12-23отсасыватель хирургическ...
# ...                                                 ...
# 6142  наумова-б/н-2023-07-04отсасыватель хирургическ...
# 6143  петухов-б/н-2023-07-03отсасыватель хирургическ...
# 6174  александров-б/н-2023-06-21отсасыватель хирурги...
# 6197  коваленко-б/н-2023-07-07штатив медицинский для...
# 6254  матюшин-б/н-2023-07-17отсасыватель хирургическ...
#
# [650 rows x 9 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# # ------------------ Новый ключ Ключ_3 ФИО НОМЕР (если цифровой) Дата выдачи Если не цифровой - то название ПРИБОРА--------------</div>

# %%
# ------------------ Новый ключ Ключ_3 ФИО НОМЕР (если цифровой) Дата выдачи --------------
df_unit.reset_index(drop= True , inplace= True )
df_unit.loc[~df_unit['Инвент_ном'].str.contains('-') == True, 'Ключ_3' ] = df_unit['Пациент'].str.split(pat=' ', expand=True)[0] + '-' + df_unit['Инвент_ном'] + '-' + (df_unit['Дата_выдачи'].dt.date).map(str) + '-' + (df_unit['Дата_возвр'].dt.date).map(str) + df_unit['Номенклатура']
df_unit.loc[df_unit['Инвент_ном'].str.contains('-') == True, 'Ключ_3' ] = df_unit['Пациент'].str.split(pat=' ', expand=True)[0] + '-' + df_unit['Инвент_ном'] + '-' + (df_unit['Дата_выдачи'].dt.date).map(str) + '-' + (df_unit['Дата_возвр'].dt.date).map(str)

# %%
# df_unit[df_unit.duplicated('Ключ_3', keep=False)].sort_values('Ключ_3')
df_unit
# Out:
#                            Пациент         ДР  \
# 0            шваков макар олегович 2014-04-14
# 1        мартынов павел дмитриевич 2010-06-20
# 2      дарчиева кристина арсеновна 2010-03-15
# 3     бабаев асланхон акмалхонович 2019-06-05
# 4      горячев владислав сергеевич 2006-12-28
# ...                            ...        ...
# 8013      агалаков юрий михайлович 1948-07-07
# 8014    баренбойм елена викторовна 1971-04-02
# 8015    шибаев владимир николаевич 1946-05-11
# 8021       матюшин сергей олегович 2002-11-14
# 8022       матюшин сергей олегович 2002-11-14
#
#                                            Номенклатура         Инвент_ном  \
# 0                      концентратор кислородный jay-5a.  004410124-0003072
# 1     аппарат для удаления выделений из дыхательных ...  004410124-0002667
# 2     аппарат искуственной вентиляции легких puritan...  004410124-0003302
# 3                      концентратор кислородный jay-5a.  004410124-0003073
# 4                        аппарат нивл wm 100 prisma30st   004410124-001791
# ...                                                 ...                ...
#

#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>функция расчета выданного оборудования в периоде c ОБОРУДОВАНИЕМ
#     </b>    </div>
# <hr>

# %%
# ------------------------------------------------- функция расчета выданного оборудования в периоде c ОБОРУДОВАНИЕМ----------------
def period_vidachi_equipment(df, dt_start, dt_finish, type_equipment, krome_text='#####'):
    type_equipment = type_equipment.lower()
    df['Номенклатура'] = df['Номенклатура'].str.lower()
    
    df = df.loc[
                (df['Номенклатура'].str.contains(type_equipment) == True)
                 & (df['Номенклатура'].str.contains(krome_text) != True)   ]
    
    
    df = df.loc[  (df['Дата_выдачи'] < finish ) 
            &
             ( (df['Дата_возвр'] >= start) | (df['Дата_возвр'].isna()))]
    
    # ------------------------------------------------------------------------------уникальные ПАЦИЕНТЫ -------     
    count_uniq_pacients = len(df.Пациент.unique()) 
    # ------------------------------------------------------------------------------уникальные Инвентарные номера -------     
    count_uniq_numbers = len(df.Инвент_ном.unique())
    # --------------------------------------------------------------------------количество выдач ЭТОГО типа ПРИБОРА ВСЕГО (по Инвентарному номеру) -------     
    used_oborud = len(df.Инвент_ном) 
    # ------------------------------------------------------------------------------количество ПОВТОРНЫХ выдач по Инвентарному номеру -------     
    duplicate_numbers = len(df.Инвент_ном) - len(df.Инвент_ном.unique())
 # ------------------------------------------------------------------------------перечень возможных наименований по части слова  -------     
    text_name_pik =  df.Номенклатура.unique()
    
    return df,  count_uniq_pacients,   count_uniq_numbers, used_oborud, duplicate_numbers, text_name_pik

# %% [markdown]
# ####
# <div class="alert alert-block alert-success">
#     <!-- -info-warning-success-danger>   -->
# <font size=5>
# <b>Считаем сколько уникальны пациентов
#     </b>    </div>
# <hr>

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - нужно для обнуления ненужных слов в датафрейме'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'ventilogic'
krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __ventilogic__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __61__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __81__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __106__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __25__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# аппарат для вентиляции легких ventilogic вариант исполнения ventilogic  plus с принадлежностями
# аппарат для вентиляции легких ventilogic с принадлежностями, вариант исполнения ventilogic ls произв
# аппарат искусственной вентиляции легких для проведения ивл/нивл (ventilogic ls)
# аппарат для вентиляции легких ventilogic с принадлежностями, вариант исполнения ventilogic plus
# аппарат для вентиляции легких ventilogic с принадлежностями, вариант исполнения  ventilogic ls
# аппарат для вентиляции легких ventilogic с принадлежностями, вариант исполнения ventilogic ls
# аппарат для вентиляции легких ventilogic вариант исполнения ventilogic plus с принадлежностями
# аппарат для вентиляции легких ventilogic с принадлежностями, вариант исполнения ventilogic ls производства lowenstein medical technology gmbh + co. kg
# аппарат для вентиляции легких ventilogic вариант исполнения ventilogic ls с принадлежностями
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - нужно для обнуления ненужных слов в датафрейме'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'VIVO 40'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __VIVO 40__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __38__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __36__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __40__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __4__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# аппарат для обеспечения неинвазивной дыхательной поддержки vivo с принадлежностями (vivo 40)
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - нужно для обнуления ненужных слов в датафрейме'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 

# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __"armed", вариант исполнения: 7d__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __172__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __173__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __187__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __14__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# отсасыватель хирургический электрический "armed", вариант исполнения: 7d
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = '"armed", вариант исполнения: 7е-а'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __"armed", вариант исполнения: 7е-а__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __96__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __76__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __97__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __21__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# отсасыватель хирургический электрический "armed", вариант исполнения: 7е-а
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'подставка-держатель для аппарата ивл puritan bennet 560'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]cv
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __подставка-держатель для аппарата ивл puritan bennet 560__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __22__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __20__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __25__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __5__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# подставка-держатель для аппарата ивл puritan bennet 560 ref.10000464 (стойка)
# подставка-держатель для аппарата ивл puritan bennet 560
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Nellcor Bedside SpO2'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Nellcor Bedside SpO2__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __22__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __22__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __23__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __1__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# пульсоксиметр (аппарат мониторинга пациента) nellcor bedside spo2, ref. 10005941
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Пульсоксиметр PM-60'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Пульсоксиметр PM-60__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __35__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __35__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __37__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __2__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# пульсоксиметр pm-60
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Пульсоксиметр серии MD300'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Пульсоксиметр серии MD300__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __54__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __51__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __59__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __8__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# пульсоксиметр серии md300, с принадлежностями исполнения: md300m
# пульсоксиметр серии md300, с принадлежностями исполнения: md300m из
# пульсоксиметр серии md300, с принадлежностями исполнения: md300m, китай
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'модель М70А'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __модель М70А__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __97__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __1__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __99__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __98__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# пульсоксиметр, модель м70а (педиатрический)
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'модель М70В'
# krome = 'тележка'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __модель М70В__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __59__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __1__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __62__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __61__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# пульсоксиметр, модель м70в (взрослый размер)
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = '"МЕГИДЕЗ"'
# krome = 'тележка'
# 'Рециркулятор бактерицидный для обеззараживания воздуха, на передвижной платформе "МЕГИДЕЗ" РБОВ 913-"МСК"'

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __"МЕГИДЕЗ"__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __76__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __76__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __81__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __5__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# рециркулятор бактерицидный для обеззараживания воздуха, на передв. платформе "мегидез" рбов
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'МЕГИДЕЗ'
# krome = 'тележка'
# Рециркулятор бактерицидный для обеззараживания воздуха, на передвижной платформе "МЕГИДЕЗ" РБОВ 913-"МСК"'
# Рециркулятор бактерицидный для обеззараживания воздуха, настенный "МЕГИДЕЗ" РБОВ 913-"МСК"

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __МЕГИДЕЗ__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __76__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __76__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __81__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __5__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# рециркулятор бактерицидный для обеззараживания воздуха, на передв. платформе "мегидез" рбов
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'PARI BOY Classic'
# krome = 'тележка'
# Система ингаляционная (ингалятор, небулайзер) PARI без подогрева PARI BOY Classic (тип 130)

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __PARI BOY Classic__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __43__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __43__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __44__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __1__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# система ингаляционная pari без подогрева pari boy classic (тип 130)
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'The Vest Airway Clearance System'
# krome = 'тележка'
# Система очистки дыхательных путей «The Vest Airway Clearance System, модель 105»

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __The Vest Airway Clearance System__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __11__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __11__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __11__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# система очистки дыхательных путей "the vest airway clearance system, модель 105" с принадлежностями
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Yang Kun YK-800'
# krome = 'тележка'
# Система очистки дыхательных путей «The Vest Airway Clearance System, модель 105»

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Yang Kun YK-800__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __0__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __0__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __0__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'BIPAP'
# krome = 'тележка'
# BIPAP A40 Philips Respironics A40

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __BIPAP__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __18__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __18__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __18__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# система поддержания положительного давления в дыхательных путях bipap, вариант исполнения: bipap a40
# система поддержания положительного давления в дыхательных путях bipap вариант исполнения bipap а40 с принадлежностями
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Тележка'
# krome = 'тележка'
# BIPAP A40 Philips Respironics A40

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Тележка__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __1__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __1__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __1__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# тележка для ventilogic ls
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Увлажнитель дыхательных смесей VADI VH-2000'
# krome = 'тележка'
# Увлажнитель дыхательных смесей MR810

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Увлажнитель дыхательных смесей VADI VH-2000__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __25__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __26__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __28__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __2__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# увлажнитель дыхательных смесей vadi vh-2000 для аппаратов ивл, c принадлежностями
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'ТЕВЛАР'
# krome = 'тележка'
# Увлажнитель дыхательных смесей MR810

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __ТЕВЛАР__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __5__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __5__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __5__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# увлажнитель дыхательных смесей тевлар-"уомз"
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Штатив для длительных инфузионных вливаний'
# krome = 'тележка'
# Увлажнитель дыхательных смесей MR810

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Штатив для длительных инфузионных вливаний__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __3__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __1__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __3__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __2__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# штатив для длительных инфузионных вливаний на трех опорах шв -"дзмо"белый
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'ВРАР System'
# krome = 'тележка'
# ИВЛ ВРАР System, вариант исполнения Т-30Т

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __ВРАР System__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __16__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __15__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __16__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __1__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# аппарат для искусственной вентиляции легких с постоянным положительнымдавлением врар system, вариант исполнения т-30т
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'VIVO30'
# krome = 'тележка'
# ИВЛ ВРАР System, вариант исполнения Т-30Т

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __VIVO30__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __0__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __0__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __0__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Mark'
# krome = 'тележка'
# Mark 5 Nuvo Lite

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Mark__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __130__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __72__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __132__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __60__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# концентратор кислорода с принадлежностями (концентратор кислорода для длительной кислородотерапии mark5 nivolite)
# концентратор кислорода для длительной кослородотерапииmark 5 nuvolite с принадлежностями
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'enteroport plus'
# krome = 'amika'
# Mark 5 Nuvo Lite

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __enteroport plus__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __4__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __4__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __4__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __0__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# насос для энтерального питания энтеропор плюс (enteroport plus) с принадлежностями
# ****************************************************************************************************************************************************************************

# %%
# -----------выдано в 2021 году. Сколко уникальны пациентов
krome = '@не удалять - обязательно наличие для обнуления ненужных слов в датафрейме - КОСТЫЛЬ'
start = '2022-07-01'
finish = '2023-07-01'

# oborud = ''
oborud = 'Пульсоксиметр'
# krome = 'amika'
# Mark 5 Nuvo Lite

df_data = df_unit

df_ = period_vidachi_equipment(df_data, start, finish, oborud, krome)

df_pacients = df_[1]
df_oborud = df_[2]
df_used_oboruds = df_[3]
df_duplicate_numbers = df_[4]
text_name_pik = df_[5]


a = f'Статистика выдачи оборудования РЦ в период с {start.split("-")[2]}.{start.split("-")[1]}.{start.split("-")[0]} по {finish.split("-")[2]}.{finish.split("-")[1]}.{finish.split("-")[0]}: '
display_markdown(f''' # {a}
| Параметр | Количество| 
|---:|:-|
| В названии прибра присутствует текст | __{oborud}__ | 
| Количество уникальных пациентов, получивших оборудование в рассм.период| __{df_pacients}__ | 
| Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __{df_oborud}__ | 
| Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __{df_used_oboruds}__ | 
| Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __{df_duplicate_numbers}__ | 

* для получения датафрейма --> df_[0]  
''', raw=True)
print(f'****************************************************************************************************************************************************************************')
for i in text_name_pik:
    print(i)
print(f'****************************************************************************************************************************************************************************')
# Out:
#  # Статистика выдачи оборудования РЦ в период с 01.07.2022 по 01.07.2023:
# | Параметр | Количество|
# |---:|:-|
# | В названии прибра присутствует текст | __Пульсоксиметр__ |
# | Количество уникальных пациентов, получивших оборудование в рассм.период| __271__ |
# | Количество уникальных ПРИБОРОВ (по инвент.номеру), выданных в рассм.период| __127__ |
# | Количество выдач ПРИБОРА (по инвент.номеру) в рассм.период (оборачива-емость)| __298__ |
# | Количество повторных выдач ПРИБОРОВ (по инвент.номеру)| __171__ |
#
# * для получения датафрейма --> df_[0]
# ****************************************************************************************************************************************************************************
# пульсоксиметр, модель м70в (взрослый размер)
# пульсоксиметр серии md300, с принадлежностями исполнения: md300m
# пульсоксиметр (аппарат мониторинга пациента) nellcor bedside spo2, ref. 10005941
# пульсоксиметр pm-60
# пульсоксиметр, модель м70а (педиатрический)
# пульсоксиметр серии md300, с принадлежностями исполнения: md300m из
# пульсоксиметр md300m с универсальным датчиком
# пульсоксиметр серии md300, с принадлежностями исполнения: md300m, китай
# ****************************************************************************************************************************************************************************

# %%
df_[0]
# Out:
#                            Пациент         ДР  \
# 3863      багирова айнура набиевна 2015-03-15
# 3864     черный егор александрович 2005-05-02
# 3865  воронова елизавета андреевна 2022-08-13
# 3866     богоцкой федор алексеевич 2009-01-30
#
#                                            Номенклатура        Инвент_ном  \
# 3863  насос для энтерального питания энтеропор плюс ...  004410124-000482
# 3864  насос для энтерального питания энтеропор плюс ...  004410124-000479
# 3865  насос для энтерального питания энтеропор плюс ...  004410124-000477
# 3866  насос для энтерального питания энтеропор плюс ...  004410124-000475
#
#      Дата_выдачи Дата_возвр                                            Ключ  \
# 3863  2021-04-29        NaT  багирова2015-03-15-004410124-000482-2021-04-29
# 3864  2021-05-25        NaT    черный2005-05-02-004410124-000479-2021-05-25
# 3865  2023-05-19        NaT  воронова2022-08-13-004410124-000477-2023-05-19
# 3866  2021-07-10 2023-02-15  богоцкой2009-01-30-004410124-000475-2021-07-10
#
#      Источник                                             Ключ_2  \
# 3863    goole  багирова-004410124-000482-2021-04-29насос для ...
# 3864    goole  черный-004410124-000479-2021-05-25насос для эн...
# 3865    goole  воронова-004410124-000477-2023-05-19насос для ...
# 3866    goole  богоцкой-004410124-000475-2021-07-10насос для ...
#
#                                                Ключ_3
# 3863         багирова-004410124-000482-2021-04-29-NaT
# 3864           черный-004410124-000479-2021-05-25-NaT
# 3865         воронова-004410124-000477-2023-05-19-NaT
# 3866  богоцкой-004410124-000475-2021-07-10-2023-02-15

# %%
df_[0]
# Out:
#                                    Пациент         ДР  \
# 504            хотынская варвара сергеевна 2020-09-01
# 532            дорожинский марк алексеевич 2021-04-18
# 560             якупов павел александрович 2021-08-21
# 582                архипов михаил павлович 2005-11-23
# 595                сикоева мария тимуровна 2016-03-13
# ...                                    ...        ...
# 2793            гончаров максим дмитриевич 2009-07-08
# 2843           пардаева аиша акмалджоновна 2020-09-22
# 2893               шатов лев александрович 2015-12-11
# 2918  омаров магомедрасул ибрагимхалилович 2005-07-06
# 6934               архипов михаил павлович 2005-11-23
